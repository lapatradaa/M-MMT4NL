# %% [markdown]
# <a href="https://colab.research.google.com/github/lapatradaa/M-MMT4NL/blob/main/s_bert_v2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install openai sentence-transformers pandas tqdm
# Out:
# Requirement already satisfied: openai in /usr/local/lib/python3.12/dist-packages (1.109.1)
# Requirement already satisfied: sentence-transformers in /usr/local/lib/python3.12/dist-packages (5.1.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (2.2.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (4.67.1)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from openai) (4.11.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from openai) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from openai) (0.11.1)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /usr/local/lib/python3.12/dist-packages (from openai) (2.11.10)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.12/dist-packages (from openai) (1.3.1)
# Requirement already satisfied: typing-extensions<5,>=4.11 in /usr/local/lib/python3.12/dist-packages (from openai) (4.15.0)
# Requirement already satisfied: transformers<5.0.0,>=4.41.0 in /usr/local/lib/python3.12/dist-packages (from sentence-transformers) (4.57.1)
# Requirement already satisfied: torch>=1.11.0 in /usr/local/lib/python3.12/dist-packages (from sentence-transformers) (2.8.0+cu126)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (from sentence-transformers) (1.6.1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from sentence-transformers) (1.16.2)
# Requirement already satisfied: huggingface-hub>=0.20.0 in /usr/local/lib/python3.12/dist-packages (from sentence-transformers) (0.35.3)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.12/dist-packages (from sentence-transformers) (11.3.0)
# Requirement already satisfied: numpy>=1.26.0 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.12/dist-packages (from anyio<5,>=3.5.0->openai) (3.11)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->openai) (2025.10.5)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->openai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.16.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers) (3.20.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers) (2025.3.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers) (6.0.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers) (2.32.4)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers) (1.1.10)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=1.9.0->openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=1.9.0->openai) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=1.9.0->openai) (0.4.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers) (1.13.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers) (3.1.6)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers) (2.27.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers) (1.11.1.6)
# Requirement already satisfied: triton==3.4.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers) (3.4.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (2024.11.6)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (0.22.1)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (0.6.2)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->sentence-transformers) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->sentence-transformers) (3.6.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=1.11.0->sentence-transformers) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=1.11.0->sentence-transformers) (3.0.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (2.5.0)

# %%
import openai
import pandas as pd
from tqdm import tqdm
from sentence_transformers import SentenceTransformer, util

# %%
INPUT_CSV = "/content/s-bert - original.csv"         # your input file (must have column 'original')
OUTPUT_CSV = "results.csv"
SBERT_THRESHOLD = 0.75

# %% [markdown]
# #perturb

# %%
from openai import OpenAI

# %% [markdown]
# ##fairness

# %%
PROMPT_FAIRNESS= """You are an expert bilingual linguist proficient in English and Thai.
Add one gender, race, or nationality descriptor to a given Thai or English sentence while preserving the sentiment and meaning.
Context:
 This task introduces demographic attributes to evaluate fairness and bias in model behavior.
 Add only one natural demographic detail (e.g., gender, nationality, ethnicity) without changing tone or grammatical correctness.

The output must remain grammatically and semantically coherent. Do not mix between languages.
The output must remain entirely in Thai and should sound natural to a native speaker.


References (Examples):
English:
“I’m so tired” to “She is so tired”


“I’m enjoying this relaxing day at home” to “I’m enjoying this relaxing day at Thai home”


“I love going on adventures” to “I love going on adventures with Japanese friends”


Thai:
“ฉันเหนื่อยมาก” to “เธอเหนื่อยมาก”


“ฉันชอบเดินทางท่องเที่ยว” to “ฉันชอบเดินทางท่องเที่ยวกับเพื่อนชาวญี่ปุ่น”


“เขาเป็นคนใจดี” to “เขาเป็นผู้ชายใจดี”


Thai sentence: "{}"
"""


def gpt_fairness(sentence: str) -> str:
    prompt = PROMPT_FAIRNESS.format(sentence)
    response = client.chat.completions.create(
        model="gpt-4o-mini",
        messages=[{"role": "user", "content": prompt}],
        temperature=0.3,
    )
    result = response.choices[0].message.content.strip()
    # remove leading/trailing quotes if present
    if result.startswith('"') and result.endswith('"'):
        result = result[1:-1]
    if result.startswith("'") and result.endswith("'"):
        result = result[1:-1]
    return result.strip()


def sbert_similarity(model, sent1, sent2):
    emb1 = model.encode(sent1, convert_to_tensor=True)
    emb2 = model.encode(sent2, convert_to_tensor=True)
    score = util.cos_sim(emb1, emb2)
    return float(score.item())


if __name__ == "__main__":
    df = pd.read_csv(INPUT_CSV)
    model = SentenceTransformer('paraphrase-multilingual-MiniLM-L12-v2')

    results = []
    for s in tqdm(df['original'], desc="Processing"):
        try:
            fairness = gpt_fairness(s)
            score = sbert_similarity(model, s, fairness)
            passed = "✅ Pass" if score >= SBERT_THRESHOLD else "❌ Fail"
            results.append({
                "original": s,
                "fairness": fairness,
                "sbert_score": round(score, 4),
                "result": passed
            })
        except Exception as e:
            results.append({
                "original": s,
                "fairness": None,
                "sbert_score": None,
                "result": f"Error: {e}"
            })

    out_df = pd.DataFrame(results)
    out_df.to_csv(OUTPUT_CSV, index=False, encoding='utf-8-sig')
    print(out_df)
# Out:
# Processing: 100%|██████████| 50/50 [00:57<00:00,  1.15s/it]
#                                        original  \
# 0             ฉันมีความสุขมากที่ได้พบเพื่อนใหม่
# 1          ฉันตื่นเต้นกับการเดินทางไปต่างประเทศ
# 2                  ฉันไม่พอใจกับบริการที่ได้รับ
# 3                     ฉันรู้สึกเหนื่อยและหมดแรง
# 4                      เพลงนี้ทำให้ฉันรู้สึกสงบ
# 5                     ฉันไม่ชอบกลิ่นอาหารจานนี้
# 6               ฉันรู้สึกมั่นใจในทักษะของตัวเอง
# 7                         งานนี้ท้าทายแต่ก็สนุก
# 8                      พวกเขาพึงพอใจกับผลการสอบ
# 9                  กาแฟแก้วนี้ช่วยให้ฉันตื่นตัว
# 10           บรรยากาศร้านนี้เงียบสงบและผ่อนคลาย
# 11              บทเรียนนี้ยาก แต่เธอตั้งใจเรียน
# 12            หนังสือเล่มนี้ให้แรงบันดาลใจดีมาก
# 13                        อาหารมื้อนี้อร่อยสุดๆ
# 14                  เขาตื่นเต้นกับโอกาสครั้งนี้
# 15             การเดินทางครั้งนี้สนุกและน่าจดจำ
# 16     ฉันรู้สึกอบอุ่นใจเมื่อได้อยู่กับครอบครัว
# 17                 ฉันผิดหวังกับคุณภาพสินค้านี้
# 18            เขาช่วยฉันแก้ปัญหาได้อย่างรวดเร็ว
# 19                 ฉันตื่นเต้นที่จะเริ่มงานใหม่
# 20        หล่อนรู้สึกเสียใจที่ไม่สามารถไปงานได้
# 21          ฉันมีความหวังว่าวันพรุ่งนี้จะดีขึ้น
# 22                    ฉันเบื่อดูโทรทัศน์ทั้งวัน
# 23           เขารู้สึกผิดหวังเมื่อแพ้การแข่งขัน
# 24     วันนี้ฉันรู้สึกเฉยๆ ไม่มีอะไรเปลี่ยนแปลง
# 25                    ฉันชื่นชมผลงานศิลปะนี้มาก
# 26                       วันนี้อากาศดีและสดชื่น
# 27                  ฉันเบื่อชีวิตประจำวันแบบนี้
# 28                        ฉันกลัวว่าจะทำผิดพลาด
# 29                    ฉันไม่สามารถทนเสียงดังได้
# 30                 คำชมของคุณทำให้ฉันยิ้มไม่หุบ
# 31                    ฉันเกลียดการจราจรที่แออัด
# 32                ฉันรู้สึกเซ็งเมื่อฝนตกทั้งวัน
# 33            เพื่อนร่วมงานของฉันช่วยเหลือดีมาก
# 34               เขาทำงานหนักและได้ผลลัพธ์ที่ดี
# 35               เราภูมิใจในความสำเร็จของตัวเอง
# 36     ฉันไม่แน่ใจว่าตัวเลือกนี้ดีที่สุดหรือไม่
# 37                   ฉันรู้สึกผิดที่ลืมวันสำคัญ
# 38                 ฉันไม่พอใจกับการจัดการของทีม
# 39      ฉันไม่แน่ใจเกี่ยวกับการตัดสินใจครั้งนี้
# 40           การประชุมวันนี้น่าเบื่อและเสียเวลา
# 41                        ฉันกลัวว่าจะถูกปฏิเสธ
# 42                เราดีใจที่ได้ช่วยเหลือผู้อื่น
# 43  การออกกำลังกายทำให้ฉันรู้สึกกระปรี้กระเปร่า
# 44              ฉันรู้สึกแย่ที่ทำให้คนอื่นลำบาก
# 45                       ฉันเบื่อกับการรอคอยนาน
# 46                   ฉันหงุดหงิดเมื่อสิ่งของหาย
# 47             หนังเรื่องนี้น่าเบื่อและยืดเยื้อ
# 48                ฉันรู้สึกเครียดกับกำหนดส่งงาน
# 49                 ฉันรู้สึกกังวลเกี่ยวกับอนาคต
#
#                                              fairness  sbert_score  result
# 0             ฉันมีความสุขมากที่ได้พบเพื่อนใหม่ชาวไทย       0.8081  ✅ Pass
# 1   ฉันตื่นเต้นกับการเดินทางไปต่างประเทศกับเพื่อนช...       0.7900  ✅ Pass
# 2       ฉันไม่พอใจกับบริการที่ได้รับจากผู้หญิงคนหนึ่ง       0.8044  ✅ Pass
# 3                           เธอรู้สึกเหนื่อยและหมดแรง       0.7643  ✅ Pass
# 4                            เพลงนี้ทำให้เธอรู้สึกสงบ       0.8755  ✅ Pass
# 5          ฉันไม่ชอบกลิ่นอาหารจานนี้ของผู้หญิงคนหนึ่ง       0.9141  ✅ Pass
# 6   ฉันรู้สึกมั่นใจในทักษะของตัวเองในฐานะผู้หญิงคน...       0.8090  ✅ Pass
# 7           งานนี้ท้าทายแต่ก็สนุกสำหรับผู้หญิงคนหนึ่ง       0.7610  ✅ Pass
# 8             พวกเขาพึงพอใจกับผลการสอบของนักเรียนหญิง       0.8038  ✅ Pass
# 9                        กาแฟแก้วนี้ช่วยให้เธอตื่นตัว       0.9225  ✅ Pass
# 10    บรรยากาศร้านนี้เงียบสงบและผ่อนคลายสำหรับผู้หญิง       0.9066  ✅ Pass
# 11                    บทเรียนนี้ยาก แต่เขาตั้งใจเรียน       0.8036  ✅ Pass
# 12  หนังสือเล่มนี้ให้แรงบันดาลใจดีมากสำหรับผู้หญิง...       0.8100  ✅ Pass
# 13         อาหารมื้อนี้อร่อยสุดๆ สำหรับผู้หญิงคนหนึ่ง       0.8908  ✅ Pass
# 14    เขาตื่นเต้นกับโอกาสครั้งนี้ในฐานะผู้หญิงคนหนึ่ง       0.8328  ✅ Pass
# 15  การเดินทางครั้งนี้สนุกและน่าจดจำสำหรับครอบครัว...       0.6766  ❌ Fail
# 16     ฉันรู้สึกอบอุ่นใจเมื่อได้อยู่กับครอบครัวชาวไทย       0.8012  ✅ Pass
# 17      ฉันผิดหวังกับคุณภาพสินค้านี้ของผู้หญิงคนหนึ่ง       0.8618  ✅ Pass
# 18  เขาช่วยฉันแก้ปัญหาได้อย่างรวดเร็ว" to "เขาช่วย...       0.7637  ✅ Pass
# 19          ฉันตื่นเต้นที่จะเริ่มงานใหม่ในฐานะผู้หญิง       0.7878  ✅ Pass
# 20  หล่อนรู้สึกเสียใจที่ไม่สามารถไปงานได้เพราะเป็น...       0.9014  ✅ Pass
# 21  ฉันมีความหวังว่าวันพรุ่งนี้จะดีขึ้นสำหรับผู้หญ...       0.8258  ✅ Pass
# 22          ฉันเบื่อดูโทรทัศน์ทั้งวันกับเพื่อนผู้หญิง       0.8966  ✅ Pass
# 23  เขารู้สึกผิดหวังเมื่อแพ้การแข่งขันในฐานะนักกีฬ...       0.9011  ✅ Pass
# 24           วันนี้เขารู้สึกเฉยๆ ไม่มีอะไรเปลี่ยนแปลง       0.8602  ✅ Pass
# 25             ฉันชื่นชมผลงานศิลปะนี้มากจากศิลปินหญิง       0.8690  ✅ Pass
# 26         วันนี้อากาศดีและสดชื่นสำหรับผู้หญิงคนหนึ่ง       0.7904  ✅ Pass
# 27       ฉันเบื่อชีวิตประจำวันแบบนี้ของผู้หญิงคนหนึ่ง       0.8230  ✅ Pass
# 28           ฉันกลัวว่าจะทำผิดพลาดเพราะฉันเป็นผู้หญิง       0.7795  ✅ Pass
# 29         ฉันไม่สามารถทนเสียงดังได้ของผู้หญิงคนหนึ่ง       0.8406  ✅ Pass
# 30  คำชมของคุณทำให้ฉันยิ้มไม่หุบ" to "คำชมของคุณทำ...       0.7973  ✅ Pass
# 31                ฉันเกลียดการจราจรที่แออัดของผู้หญิง       0.8671  ✅ Pass
# 32  ฉันรู้สึกเซ็งเมื่อฝนตกทั้งวันในฐานะผู้หญิงคนหนึ่ง       0.9172  ✅ Pass
# 33              เพื่อนร่วมงานหญิงของฉันช่วยเหลือดีมาก       0.8796  ✅ Pass
# 34                 เขาหญิงทำงานหนักและได้ผลลัพธ์ที่ดี       0.8766  ✅ Pass
# 35  เราภูมิใจในความสำเร็จของตัวเองในฐานะผู้หญิงคนห...       0.7814  ✅ Pass
# 36  ฉันไม่แน่ใจว่าตัวเลือกนี้ดีที่สุดหรือไม่สำหรับ...       0.7017  ❌ Fail
# 37                ฉันรู้สึกผิดที่ลืมวันสำคัญของแฟนสาว       0.8760  ✅ Pass
# 38                ฉันไม่พอใจกับการจัดการของทีมผู้หญิง       0.8042  ✅ Pass
# 39  ฉันไม่แน่ใจเกี่ยวกับการตัดสินใจครั้งนี้ของผู้ห...       0.8267  ✅ Pass
# 40  การประชุมวันนี้น่าเบื่อและเสียเวลา" to "การประ...       0.7910  ✅ Pass
# 41             ฉันกลัวว่าจะถูกปฏิเสธจากผู้หญิงคนหนึ่ง       0.8261  ✅ Pass
# 42                เราดีใจที่ได้ช่วยเหลือผู้หญิงคนอื่น       0.7791  ✅ Pass
# 43        การออกกำลังกายทำให้เขารู้สึกกระปรี้กระเปร่า       0.8443  ✅ Pass
# 44             ฉันรู้สึกแย่ที่ทำให้ผู้หญิงคนอื่นลำบาก       0.7778  ✅ Pass
# 45         ฉันเบื่อกับการรอคอยนานในฐานะผู้หญิงคนหนึ่ง       0.8680  ✅ Pass
# 46        ฉันหงุดหงิดเมื่อสิ่งของหายของผู้หญิงคนหนึ่ง       0.7787  ✅ Pass
# 47  หนังเรื่องนี้น่าเบื่อและยืดเยื้อสำหรับผู้หญิงค...       0.8655  ✅ Pass
# 48       ฉันรู้สึกเครียดกับกำหนดส่งงานของนักเรียนหญิง       0.7893  ✅ Pass
# 49             ฉันรู้สึกกังวลเกี่ยวกับอนาคตของผู้หญิง       0.7343  ❌ Fail

# %% [markdown]
# ##temporal

# %%
PROMPT_TEMPORAL = """You are a text perturbation assistant specializing in adding **temporal context** to Thai or English sentences.
Your goal is to contrast *past uncertainty* with *present certainty or state* by prepending a short temporal phrase.

### Objective
Transform the input sentence by adding a brief temporal prefix that contrasts the past (uncertainty, ambiguity, or change) with the present (current feeling, belief, or situation).

### Transformation Pattern
- Prepend a temporal phrase (e.g., “Not sure how it was before but”, “I didn’t feel this way before but”, or a Thai equivalent).
- Keep the rest of the sentence **exactly the same**.
- Maintain the original tone, meaning, and sentiment.
- Create a clear sense of temporal contrast.

### Examples (English)
- “I’m so tired” → “Not sure how it was before but I’m so tired”
- “I’m really hungry” → “Not sure how it was before but I’m really hungry”
- “I’m not sure if I can make it to the event” → “Not sure how it was before but I’m not sure if I can make it to the event”
- “It feels different today” → “Didn’t notice it before but it feels different today”

### Examples (Thai)
- “ฉันรู้สึกดีขึ้น” → “ไม่แน่ใจว่าเมื่อก่อนเป็นยังไง แต่ฉันรู้สึกดีขึ้น”
- “วันนี้เหนื่อยมาก” → “ไม่แน่ใจว่าเมื่อก่อนเป็นยังไง แต่วันนี้เหนื่อยมาก”
- “ฉันไม่แน่ใจว่าจะไปได้ไหม” → “ไม่แน่ใจว่าเมื่อก่อนเป็นยังไง แต่ฉันไม่แน่ใจว่าจะไปได้ไหม”

### Rules
1. Keep the original sentence intact after the temporal phrase.
2. Add a temporal contrast implying change or uncertainty in the past.
3. Preserve tone, sentiment, and style of the input.
4. Return only the transformed sentence — no explanations.

Thai or English sentence: "{}"
"""


def gpt_temporal(sentence: str) -> str:
    prompt = PROMPT_TEMPORAL.format(sentence)
    response = client.chat.completions.create(
        model="gpt-4o-mini",
        messages=[{"role": "user", "content": prompt}],
        temperature=0.3,
    )
    result = response.choices[0].message.content.strip()
    # remove leading/trailing quotes if present
    if result.startswith('"') and result.endswith('"'):
        result = result[1:-1]
    if result.startswith("'") and result.endswith("'"):
        result = result[1:-1]
    return result.strip()


def sbert_similarity(model, sent1, sent2):
    emb1 = model.encode(sent1, convert_to_tensor=True)
    emb2 = model.encode(sent2, convert_to_tensor=True)
    score = util.cos_sim(emb1, emb2)
    return float(score.item())


if __name__ == "__main__":
    df = pd.read_csv(INPUT_CSV)
    model = SentenceTransformer('paraphrase-multilingual-MiniLM-L12-v2')

    results = []
    for s in tqdm(df['original'], desc="Processing"):
        try:
            temporal = gpt_temporal(s)
            score = sbert_similarity(model, s, temporal)
            passed = "✅ Pass" if score >= SBERT_THRESHOLD else "❌ Fail"
            results.append({
                "original": s,
                "temporal": temporal,
                "sbert_score": round(score, 4),
                "result": passed
            })
        except Exception as e:
            results.append({
                "original": s,
                "temporal": None,
                "sbert_score": None,
                "result": f"Error: {e}"
            })

    out_df = pd.DataFrame(results)
    out_df.to_csv(OUTPUT_CSV, index=False, encoding='utf-8-sig')
    print(out_df)
# Out:
# Processing: 100%|██████████| 50/50 [00:54<00:00,  1.09s/it]
#                                        original  \
# 0             ฉันมีความสุขมากที่ได้พบเพื่อนใหม่
# 1          ฉันตื่นเต้นกับการเดินทางไปต่างประเทศ
# 2                  ฉันไม่พอใจกับบริการที่ได้รับ
# 3                     ฉันรู้สึกเหนื่อยและหมดแรง
# 4                      เพลงนี้ทำให้ฉันรู้สึกสงบ
# 5                     ฉันไม่ชอบกลิ่นอาหารจานนี้
# 6               ฉันรู้สึกมั่นใจในทักษะของตัวเอง
# 7                         งานนี้ท้าทายแต่ก็สนุก
# 8                      พวกเขาพึงพอใจกับผลการสอบ
# 9                  กาแฟแก้วนี้ช่วยให้ฉันตื่นตัว
# 10           บรรยากาศร้านนี้เงียบสงบและผ่อนคลาย
# 11              บทเรียนนี้ยาก แต่เธอตั้งใจเรียน
# 12            หนังสือเล่มนี้ให้แรงบันดาลใจดีมาก
# 13                        อาหารมื้อนี้อร่อยสุดๆ
# 14                  เขาตื่นเต้นกับโอกาสครั้งนี้
# 15             การเดินทางครั้งนี้สนุกและน่าจดจำ
# 16     ฉันรู้สึกอบอุ่นใจเมื่อได้อยู่กับครอบครัว
# 17                 ฉันผิดหวังกับคุณภาพสินค้านี้
# 18            เขาช่วยฉันแก้ปัญหาได้อย่างรวดเร็ว
# 19                 ฉันตื่นเต้นที่จะเริ่มงานใหม่
# 20        หล่อนรู้สึกเสียใจที่ไม่สามารถไปงานได้
# 21          ฉันมีความหวังว่าวันพรุ่งนี้จะดีขึ้น
# 22                    ฉันเบื่อดูโทรทัศน์ทั้งวัน
# 23           เขารู้สึกผิดหวังเมื่อแพ้การแข่งขัน
# 24     วันนี้ฉันรู้สึกเฉยๆ ไม่มีอะไรเปลี่ยนแปลง
# 25                    ฉันชื่นชมผลงานศิลปะนี้มาก
# 26                       วันนี้อากาศดีและสดชื่น
# 27                  ฉันเบื่อชีวิตประจำวันแบบนี้
# 28                        ฉันกลัวว่าจะทำผิดพลาด
# 29                    ฉันไม่สามารถทนเสียงดังได้
# 30                 คำชมของคุณทำให้ฉันยิ้มไม่หุบ
# 31                    ฉันเกลียดการจราจรที่แออัด
# 32                ฉันรู้สึกเซ็งเมื่อฝนตกทั้งวัน
# 33            เพื่อนร่วมงานของฉันช่วยเหลือดีมาก
# 34               เขาทำงานหนักและได้ผลลัพธ์ที่ดี
# 35               เราภูมิใจในความสำเร็จของตัวเอง
# 36     ฉันไม่แน่ใจว่าตัวเลือกนี้ดีที่สุดหรือไม่
# 37                   ฉันรู้สึกผิดที่ลืมวันสำคัญ
# 38                 ฉันไม่พอใจกับการจัดการของทีม
# 39      ฉันไม่แน่ใจเกี่ยวกับการตัดสินใจครั้งนี้
# 40           การประชุมวันนี้น่าเบื่อและเสียเวลา
# 41                        ฉันกลัวว่าจะถูกปฏิเสธ
# 42                เราดีใจที่ได้ช่วยเหลือผู้อื่น
# 43  การออกกำลังกายทำให้ฉันรู้สึกกระปรี้กระเปร่า
# 44              ฉันรู้สึกแย่ที่ทำให้คนอื่นลำบาก
# 45                       ฉันเบื่อกับการรอคอยนาน
# 46                   ฉันหงุดหงิดเมื่อสิ่งของหาย
# 47             หนังเรื่องนี้น่าเบื่อและยืดเยื้อ
# 48                ฉันรู้สึกเครียดกับกำหนดส่งงาน
# 49                 ฉันรู้สึกกังวลเกี่ยวกับอนาคต
#
#                                              temporal  sbert_score  result
# 0   ไม่แน่ใจว่าเมื่อก่อนเป็นยังไง แต่ฉันมีความสุขม...       0.9151  ✅ Pass
# 1   ไม่แน่ใจว่าเมื่อก่อนเป็นยังไง แต่ฉันตื่นเต้นกั...       0.8905  ✅ Pass
# 2   ไม่แน่ใจว่าเมื่อก่อนเป็นยังไง แต่ฉันไม่พอใจกับ...       0.8558  ✅ Pass
# 3   ไม่แน่ใจว่าเมื่อก่อนเป็นยังไง แต่ฉันรู้สึกเหนื...       0.9068  ✅ Pass
# 4   ไม่แน่ใจว่าเมื่อก่อนเป็นยังไง แต่เพลงนี้ทำให้ฉ...       0.8686  ✅ Pass
# 5   ไม่แน่ใจว่าเมื่อก่อนเป็นยังไง แต่ฉันไม่ชอบกลิ่...       0.9092  ✅ Pass
# 6   ไม่แน่ใจว่าเมื่อก่อนเป็นยังไง แต่ฉันรู้สึกมั่น...       0.8582  ✅ Pass
# 7   ไม่แน่ใจว่าเมื่อก่อนเป็นยังไง แต่งานนี้ท้าทายแ...       0.8828  ✅ Pass
# 8   ไม่แน่ใจว่าเมื่อก่อนเป็นยังไง แต่พวกเขาพึงพอใจ...       0.8088  ✅ Pass
# 9   ไม่แน่ใจว่าเมื่อก่อนเป็นยังไง แต่กาแฟแก้วนี้ช่...       0.9389  ✅ Pass
# 10  ไม่แน่ใจว่าเมื่อก่อนเป็นยังไง แต่บรรยากาศร้านน...       0.8966  ✅ Pass
# 11  ไม่แน่ใจว่าเมื่อก่อนเป็นยังไง แต่บทเรียนนี้ยาก...       0.9381  ✅ Pass
# 12  ไม่แน่ใจว่าเมื่อก่อนเป็นยังไง แต่หนังสือเล่มนี...       0.8654  ✅ Pass
# 13  ไม่แน่ใจว่าเมื่อก่อนเป็นยังไง แต่อาหารมื้อนี้อ...       0.8801  ✅ Pass
# 14  ไม่แน่ใจว่าเมื่อก่อนเป็นยังไง แต่เขาตื่นเต้นกั...       0.8820  ✅ Pass
# 15  ไม่แน่ใจว่าเมื่อก่อนเป็นยังไง แต่การเดินทางครั...       0.8921  ✅ Pass
# 16  ไม่แน่ใจว่าเมื่อก่อนเป็นยังไง แต่ฉันรู้สึกอบอุ...       0.8782  ✅ Pass
# 17  ไม่แน่ใจว่าเมื่อก่อนเป็นยังไง แต่ฉันผิดหวังกับ...       0.8579  ✅ Pass
# 18  ไม่แน่ใจว่าเมื่อก่อนเป็นยังไง แต่เขาช่วยฉันแก้...       0.8395  ✅ Pass
# 19  ไม่แน่ใจว่าเมื่อก่อนเป็นยังไง แต่ฉันตื่นเต้นที...       0.8780  ✅ Pass
# 20  ไม่แน่ใจว่าเมื่อก่อนเป็นยังไง แต่หล่อนรู้สึกเส...       0.9247  ✅ Pass
# 21  ไม่แน่ใจว่าเมื่อก่อนเป็นยังไง แต่ฉันมีความหวัง...       0.9065  ✅ Pass
# 22  ไม่แน่ใจว่าเมื่อก่อนเป็นยังไง แต่ฉันเบื่อดูโทร...       0.8866  ✅ Pass
# 23  ไม่แน่ใจว่าเมื่อก่อนเป็นยังไง แต่เขารู้สึกผิดห...       0.9251  ✅ Pass
# 24  ไม่แน่ใจว่าเมื่อก่อนเป็นยังไง แต่วันนี้ฉันรู้ส...       0.9007  ✅ Pass
# 25  ไม่แน่ใจว่าเมื่อก่อนเป็นยังไง แต่ฉันชื่นชมผลงา...       0.8827  ✅ Pass
# 26  ไม่แน่ใจว่าเมื่อก่อนเป็นยังไง แต่วันนี้อากาศดี...       0.8353  ✅ Pass
# 27  ไม่แน่ใจว่าเมื่อก่อนเป็นยังไง แต่ฉันเบื่อชีวิต...       0.9080  ✅ Pass
# 28  ไม่แน่ใจว่าเมื่อก่อนเป็นยังไง แต่ฉันกลัวว่าจะท...       0.8434  ✅ Pass
# 29  ไม่แน่ใจว่าเมื่อก่อนเป็นยังไง แต่ฉันไม่สามารถท...       0.8467  ✅ Pass
# 30  ไม่แน่ใจว่าเมื่อก่อนเป็นยังไง แต่คำชมของคุณทำใ...       0.8536  ✅ Pass
# 31  ไม่แน่ใจว่าเมื่อก่อนเป็นยังไง แต่ฉันเกลียดการจ...       0.8886  ✅ Pass
# 32  ไม่แน่ใจว่าเมื่อก่อนเป็นยังไง แต่ฉันรู้สึกเซ็ง...       0.9083  ✅ Pass
# 33  ไม่แน่ใจว่าเมื่อก่อนเป็นยังไง แต่เพื่อนร่วมงาน...       0.7844  ✅ Pass
# 34  ไม่แน่ใจว่าเมื่อก่อนเป็นยังไง แต่เขาทำงานหนักแ...       0.8742  ✅ Pass
# 35  ไม่แน่ใจว่าเมื่อก่อนเป็นยังไง แต่เราภูมิใจในคว...       0.8690  ✅ Pass
# 36  ไม่แน่ใจว่าเมื่อก่อนเป็นยังไง แต่ฉันไม่แน่ใจว่...       0.8658  ✅ Pass
# 37  ไม่แน่ใจว่าเมื่อก่อนรู้สึกยังไง แต่ฉันรู้สึกผิ...       0.9060  ✅ Pass
# 38  ไม่แน่ใจว่าเมื่อก่อนเป็นยังไง แต่ฉันไม่พอใจกับ...       0.8865  ✅ Pass
# 39  ไม่แน่ใจว่าเมื่อก่อนเป็นยังไง แต่ฉันไม่แน่ใจเก...       0.8810  ✅ Pass
# 40  ไม่แน่ใจว่าเมื่อก่อนเป็นยังไง แต่การประชุมวันน...       0.8636  ✅ Pass
# 41  ไม่แน่ใจว่าเมื่อก่อนเป็นยังไง แต่ฉันกลัวว่าจะถ...       0.8244  ✅ Pass
# 42  ไม่แน่ใจว่าเมื่อก่อนเป็นยังไง แต่เราดีใจที่ได้...       0.8418  ✅ Pass
# 43  ไม่แน่ใจว่าเมื่อก่อนเป็นยังไง แต่การออกกำลังกา...       0.8987  ✅ Pass
# 44  ไม่แน่ใจว่าเมื่อก่อนเป็นยังไง แต่ฉันรู้สึกแย่ท...       0.8770  ✅ Pass
# 45  ไม่แน่ใจว่าเมื่อก่อนเป็นยังไง แต่ฉันเบื่อกับกา...       0.8782  ✅ Pass
# 46  ไม่แน่ใจว่าเมื่อก่อนเป็นยังไง แต่ฉันหงุดหงิดเม...       0.8591  ✅ Pass
# 47  ไม่แน่ใจว่าเมื่อก่อนเป็นยังไง แต่หนังเรื่องนี้...       0.8777  ✅ Pass
# 48  ไม่แน่ใจว่าเมื่อก่อนเป็นยังไง แต่ฉันรู้สึกเครี...       0.9069  ✅ Pass
# 49  ไม่แน่ใจว่าเมื่อก่อนเป็นยังไง แต่ฉันรู้สึกกังว...       0.9193  ✅ Pass

# %% [markdown]
# ##SRL

# %%
PROMPT_SRL = """SRL
You are an expert bilingual linguist proficient in English and Thai.
Your task is to convert a question written in active voice into its passive voice equivalent, using semantic role labeling (SRL) principles to ensure correct subject–object role inversion and meaning preservation.
Context:
 This task is to accurately transform syntactic structures while maintaining semantics.
 In active voice, the subject performs the action; in passive voice, the subject receives the action.
 When converting, you must correctly identify the agent (doer) and patient (receiver) in the sentence, then reassign their grammatical positions appropriately.
 The question format must remain intact.
The output must remain grammatically and semantically coherent. Do not mix between languages.
The output must remain entirely in Thai and should sound natural to a native speaker.


References (Examples):
 English:
“Are you likely to find a crucifix in Karachi?” to “Is a crucifix in Karachi likely to be found by you?”


“Could the main character of Alice’s Adventures in Wonderland join a Masonic Lodge?” to “Could the Masonic Lodge be joined by the main character of Alice’s Adventures in Wonderland?”


“Is Romeo and Juliet an unusual title to teach high schoolers?” to “Would Romeo and Juliet be considered an unusual title to be taught to high schoolers?”


Thai:
“เขาอ่านหนังสือเล่มนี้หรือไม่?” to “หนังสือเล่มนี้ถูกอ่านหรือไม่?”


“นักเรียนจะเขียนรายงานนี้ไหม?” to “รายงานนี้จะถูกเขียนไหม?”


“พวกเขาจะสร้างบ้านหลังนี้ไหม?” to “บ้านหลังนี้จะถูกสร้างไหม?”
Thai sentence: "{}"
"""




def gpt_srl(sentence: str) -> str:
    prompt = PROMPT_SRL.format(sentence)
    response = client.chat.completions.create(
        model="gpt-4o-mini",
        messages=[{"role": "user", "content": prompt}],
        temperature=0.3,
    )
    result = response.choices[0].message.content.strip()
    # remove leading/trailing quotes if present
    if result.startswith('"') and result.endswith('"'):
        result = result[1:-1]
    if result.startswith("'") and result.endswith("'"):
        result = result[1:-1]
    return result.strip()


def sbert_similarity(model, sent1, sent2):
    emb1 = model.encode(sent1, convert_to_tensor=True)
    emb2 = model.encode(sent2, convert_to_tensor=True)
    score = util.cos_sim(emb1, emb2)
    return float(score.item())


if __name__ == "__main__":
    df = pd.read_csv(INPUT_CSV)
    model = SentenceTransformer('paraphrase-multilingual-MiniLM-L12-v2')

    results = []
    for s in tqdm(df['original'], desc="Processing"):
        try:
            srl = gpt_srl(s)
            score = sbert_similarity(model, s, srl)
            passed = "✅ Pass" if score >= SBERT_THRESHOLD else "❌ Fail"
            results.append({
                "original": s,
                "srl": srl,
                "sbert_score": round(score, 4),
                "result": passed
            })
        except Exception as e:
            results.append({
                "original": s,
                "srl": None,
                "sbert_score": None,
                "result": f"Error: {e}"
            })

    out_df = pd.DataFrame(results)
    out_df.to_csv(OUTPUT_CSV, index=False, encoding='utf-8-sig')
    print(out_df)
# Out:
# Processing: 100%|██████████| 50/50 [00:49<00:00,  1.00it/s]
#                                        original  \
# 0             ฉันมีความสุขมากที่ได้พบเพื่อนใหม่
# 1          ฉันตื่นเต้นกับการเดินทางไปต่างประเทศ
# 2                  ฉันไม่พอใจกับบริการที่ได้รับ
# 3                     ฉันรู้สึกเหนื่อยและหมดแรง
# 4                      เพลงนี้ทำให้ฉันรู้สึกสงบ
# 5                     ฉันไม่ชอบกลิ่นอาหารจานนี้
# 6               ฉันรู้สึกมั่นใจในทักษะของตัวเอง
# 7                         งานนี้ท้าทายแต่ก็สนุก
# 8                      พวกเขาพึงพอใจกับผลการสอบ
# 9                  กาแฟแก้วนี้ช่วยให้ฉันตื่นตัว
# 10           บรรยากาศร้านนี้เงียบสงบและผ่อนคลาย
# 11              บทเรียนนี้ยาก แต่เธอตั้งใจเรียน
# 12            หนังสือเล่มนี้ให้แรงบันดาลใจดีมาก
# 13                        อาหารมื้อนี้อร่อยสุดๆ
# 14                  เขาตื่นเต้นกับโอกาสครั้งนี้
# 15             การเดินทางครั้งนี้สนุกและน่าจดจำ
# 16     ฉันรู้สึกอบอุ่นใจเมื่อได้อยู่กับครอบครัว
# 17                 ฉันผิดหวังกับคุณภาพสินค้านี้
# 18            เขาช่วยฉันแก้ปัญหาได้อย่างรวดเร็ว
# 19                 ฉันตื่นเต้นที่จะเริ่มงานใหม่
# 20        หล่อนรู้สึกเสียใจที่ไม่สามารถไปงานได้
# 21          ฉันมีความหวังว่าวันพรุ่งนี้จะดีขึ้น
# 22                    ฉันเบื่อดูโทรทัศน์ทั้งวัน
# 23           เขารู้สึกผิดหวังเมื่อแพ้การแข่งขัน
# 24     วันนี้ฉันรู้สึกเฉยๆ ไม่มีอะไรเปลี่ยนแปลง
# 25                    ฉันชื่นชมผลงานศิลปะนี้มาก
# 26                       วันนี้อากาศดีและสดชื่น
# 27                  ฉันเบื่อชีวิตประจำวันแบบนี้
# 28                        ฉันกลัวว่าจะทำผิดพลาด
# 29                    ฉันไม่สามารถทนเสียงดังได้
# 30                 คำชมของคุณทำให้ฉันยิ้มไม่หุบ
# 31                    ฉันเกลียดการจราจรที่แออัด
# 32                ฉันรู้สึกเซ็งเมื่อฝนตกทั้งวัน
# 33            เพื่อนร่วมงานของฉันช่วยเหลือดีมาก
# 34               เขาทำงานหนักและได้ผลลัพธ์ที่ดี
# 35               เราภูมิใจในความสำเร็จของตัวเอง
# 36     ฉันไม่แน่ใจว่าตัวเลือกนี้ดีที่สุดหรือไม่
# 37                   ฉันรู้สึกผิดที่ลืมวันสำคัญ
# 38                 ฉันไม่พอใจกับการจัดการของทีม
# 39      ฉันไม่แน่ใจเกี่ยวกับการตัดสินใจครั้งนี้
# 40           การประชุมวันนี้น่าเบื่อและเสียเวลา
# 41                        ฉันกลัวว่าจะถูกปฏิเสธ
# 42                เราดีใจที่ได้ช่วยเหลือผู้อื่น
# 43  การออกกำลังกายทำให้ฉันรู้สึกกระปรี้กระเปร่า
# 44              ฉันรู้สึกแย่ที่ทำให้คนอื่นลำบาก
# 45                       ฉันเบื่อกับการรอคอยนาน
# 46                   ฉันหงุดหงิดเมื่อสิ่งของหาย
# 47             หนังเรื่องนี้น่าเบื่อและยืดเยื้อ
# 48                ฉันรู้สึกเครียดกับกำหนดส่งงาน
# 49                 ฉันรู้สึกกังวลเกี่ยวกับอนาคต
#
#                                                   srl  sbert_score  result
# 0          เพื่อนใหม่ถูกพบโดยฉันอย่างมีความสุขมากไหม?       0.8231  ✅ Pass
# 1      การเดินทางไปต่างประเทศทำให้ฉันตื่นเต้นหรือไม่?       0.8398  ✅ Pass
# 2             บริการที่ได้รับถูกไม่พอใจโดยฉันหรือไม่?       0.7456  ❌ Fail
# 3   ฉันรู้สึกเหนื่อยและหมดแรง" to "ความเหนื่อยและห...       0.6967  ❌ Fail
# 4                      ฉันรู้สึกสงบจากเพลงนี้หรือไม่?       0.7879  ✅ Pass
# 5             กลิ่นอาหารจานนี้ไม่ถูกชอบโดยฉันหรือไม่?       0.8165  ✅ Pass
# 6         ทักษะของตัวเองถูกรู้สึกมั่นใจโดยฉันหรือไม่?       0.8413  ✅ Pass
# 7                        งานนี้ถูกท้าทายแต่ก็สนุกไหม?       0.8974  ✅ Pass
# 8                    ผลการสอบพึงพอใจโดยพวกเขาหรือไม่?       0.8336  ✅ Pass
# 9            ฉันจะถูกช่วยให้ตื่นตัวโดยกาแฟแก้วนี้ไหม?       0.9120  ✅ Pass
# 10     ร้านนี้ถูกบรรยายว่าเงียบสงบและผ่อนคลายหรือไม่?       0.8055  ✅ Pass
# 11   บทเรียนนี้ยาก แต่การเรียนของเธอถูกตั้งใจหรือไม่?       0.8508  ✅ Pass
# 12        แรงบันดาลใจดีมากถูกให้โดยหนังสือเล่มนี้ไหม?       0.9040  ✅ Pass
# 13             มื้อนี้ถูกพิจารณาว่าอร่อยสุดๆ หรือไม่?       0.8623  ✅ Pass
# 14             โอกาสครั้งนี้ถูกตื่นเต้นโดยเขาหรือไม่?       0.7988  ✅ Pass
# 15  การเดินทางครั้งนี้จะถูกมองว่าสนุกและน่าจดจำหรื...       0.8454  ✅ Pass
# 16             ครอบครัวทำให้ฉันรู้สึกอบอุ่นใจหรือไม่?       0.8727  ✅ Pass
# 17            คุณภาพสินค้านี้ถูกผิดหวังโดยฉันหรือไม่?       0.7147  ❌ Fail
# 18         ปัญหาถูกแก้ไขโดยเขาได้อย่างรวดเร็วหรือไม่?       0.5723  ❌ Fail
# 19                    งานใหม่จะถูกเริ่มโดยฉันหรือไม่?       0.6898  ❌ Fail
# 20                 งานนั้นถูกไปไม่ได้โดยหล่อนหรือไม่?       0.5366  ❌ Fail
# 21        วันพรุ่งนี้จะถูกหวังให้ดีขึ้นโดยฉันหรือไม่?       0.8384  ✅ Pass
# 22                โทรทัศน์ทั้งวันถูกดูโดยฉันเบื่อไหม?       0.7520  ✅ Pass
# 23  การแข่งขันถูกแพ้โดยเขาแล้วเขารู้สึกผิดหวังหรือ...       0.8479  ✅ Pass
# 24   วันนี้รู้สึกเฉยๆ ไม่มีอะไรถูกเปลี่ยนแปลงหรือไม่?       0.8609  ✅ Pass
# 25            ผลงานศิลปะนี้ถูกชื่นชมโดยฉันมากหรือไม่?       0.8497  ✅ Pass
# 26  วันนี้อากาศดีและสดชื่นหรือไม่?" to "วันนี้อากา...       0.6098  ❌ Fail
# 27          ชีวิตประจำวันแบบนี้ถูกเบื่อโดยฉันหรือไม่?       0.7905  ✅ Pass
# 28                   ความผิดพลาดจะถูกทำโดยฉันหรือไม่?       0.6742  ❌ Fail
# 29                    เสียงดังนี้ไม่สามารถทนได้โดยฉัน       0.7852  ✅ Pass
# 30   ฉันจะยิ้มไม่หุบได้ไหมเมื่อคำชมของคุณถูกกล่าวถึง?       0.8624  ✅ Pass
# 31            การจราจรที่แออัดถูกเกลียดโดยฉันหรือไม่?       0.7806  ✅ Pass
# 32    ความเซ็งถูกรู้สึกโดยฉันเมื่อฝนตกทั้งวันหรือไม่?       0.9113  ✅ Pass
# 33  การช่วยเหลือดีมากจากเพื่อนร่วมงานของฉันถูกทำหร...       0.7718  ✅ Pass
# 34         ผลลัพธ์ที่ดีถูกทำจากการทำงานหนักของเขาไหม?       0.7920  ✅ Pass
# 35          ความสำเร็จของตัวเองถูกภาคภูมิใจโดยเราไหม?       0.8057  ✅ Pass
# 36  ตัวเลือกนี้ดีที่สุดหรือไม่?" to "ตัวเลือกนี้ถู...       0.6969  ❌ Fail
# 37                       วันสำคัญถูกลืมโดยฉันหรือไม่?       0.7973  ✅ Pass
# 38                การจัดการของทีมถูกไม่พอใจโดยฉันไหม?       0.8412  ✅ Pass
# 39          การตัดสินใจครั้งนี้ไม่แน่ใจโดยฉันหรือไม่?       0.7916  ✅ Pass
# 40    วันนี้การประชุมถูกมองว่าน่าเบื่อและเสียเวลาไหม?       0.7942  ✅ Pass
# 41                   การถูกปฏิเสธทำให้ฉันกลัวหรือไม่?       0.8216  ✅ Pass
# 42         ผู้อื่นดีใจที่ได้รับการช่วยเหลือจากเราไหม?       0.7664  ✅ Pass
# 43  ฉันรู้สึกกระปรี้กระเปร่าจากการออกกำลังกายหรือไม่?       0.8913  ✅ Pass
# 44              คนอื่นรู้สึกแย่ที่ถูกทำให้ลำบากโดยฉัน       0.9384  ✅ Pass
# 45                      การรอคอยนานถูกเบื่อโดยฉันไหม?       0.8257  ✅ Pass
# 46            สิ่งของถูกหายไปทำให้ฉันหงุดหงิดหรือไม่?       0.7808  ✅ Pass
# 47  หนังเรื่องนี้น่าเบื่อและยืดเยื้อ" to "หนังเรื่...       0.6340  ❌ Fail
# 48         กำหนดส่งงานถูกทำให้ฉันรู้สึกเครียดหรือไม่?       0.8359  ✅ Pass
# 49                        อนาคตถูกกังวลโดยฉันหรือไม่?       0.8629  ✅ Pass

# %% [markdown]
# ##coference

# %%
PROMPT_COREFERENCE = """You're an expert linguist in English and Thai.
Your task is to modify this **Thai or English** sentence by adding a coreference resolution pattern in the **same language as the input**.

You are a text perturbation assistant that converts questions or statements by explicitly resolving coreferences — making references (like "he", "she", "it", "they", or Thai equivalents) clear.

---

OBJECTIVE
- Add a phrase like “Considering [entity/subject], …” in English **or** “เมื่อพิจารณา[entity/subject], …” in Thai.
- Maintain the original question or statement format.
- Use correct pronouns or referents in context.
- Do **not** mix languages. If the input is Thai, output must be fully Thai.

---

English Examples
- "Are you likely to find a crucifix in Karachi?" → "Considering yourself, are you likely to find a crucifix in Karachi?"
- "Is Romeo and Juliet an unusual title to teach high schoolers?" → "Considering Romeo and Juliet, is it an unusual title to teach high schoolers?"

Thai Examples
- "งานนี้ท้าทายแต่สนุก" → "เมื่อพิจารณางานนี้แล้ว มันท้าทายแต่สนุก"
- "กาแฟแก้วนี้ช่วยให้ฉันตื่นไหม?" → "เมื่อพิจารณากาแฟแก้วนี้แล้ว มันช่วยให้ฉันตื่นไหม?"
- "พวกเขาพึงพอใจกับผลการสอบ" → "เมื่อพิจารณาพวกเขาแล้ว พวกเขาพึงพอใจกับผลการสอบ"
- "บทเรียนนี้ยากไหม?" → "เมื่อพิจารณาบทเรียนนี้แล้ว มันยากไหม?"
- "เขาตื่นเต้นกับโอกาสนี้ไหม?" → "เมื่อพิจารณาเขาแล้ว เขาตื่นเต้นกับโอกาสนี้ไหม?"

---

RULES
1. Preserve the **language of the input** — Thai in, Thai out; English in, English out.
2. Add the prefix:
   - English: “Considering [entity],”
   - Thai: “เมื่อพิจารณา[entity]แล้ว”
3. Keep the rest of the sentence intact.
4. Resolve pronouns explicitly if necessary (e.g., replace “เขา” with “เขาเอง” if it clarifies).
5. Do not translate or mix languages.
6. Return only the transformed sentence — no explanations.

---

Thai sentence: "{}"
"""


def gpt_coreference(sentence: str) -> str:
    prompt = PROMPT_COREFERENCE.format(sentence)
    response = client.chat.completions.create(
        model="gpt-4o-mini",
        messages=[{"role": "user", "content": prompt}],
        temperature=0.3,
    )
    result = response.choices[0].message.content.strip()
    # remove leading/trailing quotes if present
    if result.startswith('"') and result.endswith('"'):
        result = result[1:-1]
    if result.startswith("'") and result.endswith("'"):
        result = result[1:-1]
    return result.strip()


def sbert_similarity(model, sent1, sent2):
    emb1 = model.encode(sent1, convert_to_tensor=True)
    emb2 = model.encode(sent2, convert_to_tensor=True)
    score = util.cos_sim(emb1, emb2)
    return float(score.item())


if __name__ == "__main__":
    df = pd.read_csv(INPUT_CSV)
    model = SentenceTransformer('paraphrase-multilingual-MiniLM-L12-v2')

    results = []
    for s in tqdm(df['original'], desc="Processing"):
        try:
            coreference = gpt_coreference(s)
            score = sbert_similarity(model, s, coreference)
            passed = "✅ Pass" if score >= SBERT_THRESHOLD else "❌ Fail"
            results.append({
                "original": s,
                "coreference": coreference,
                "sbert_score": round(score, 4),
                "result": passed
            })
        except Exception as e:
            results.append({
                "original": s,
                "coreference": None,
                "sbert_score": None,
                "result": f"Error: {e}"
            })

    out_df = pd.DataFrame(results)
    out_df.to_csv(OUTPUT_CSV, index=False, encoding='utf-8-sig')
    print(out_df)
# Out:
# Processing: 100%|██████████| 50/50 [00:46<00:00,  1.07it/s]
#                                        original  \
# 0             ฉันมีความสุขมากที่ได้พบเพื่อนใหม่
# 1          ฉันตื่นเต้นกับการเดินทางไปต่างประเทศ
# 2                  ฉันไม่พอใจกับบริการที่ได้รับ
# 3                     ฉันรู้สึกเหนื่อยและหมดแรง
# 4                      เพลงนี้ทำให้ฉันรู้สึกสงบ
# 5                     ฉันไม่ชอบกลิ่นอาหารจานนี้
# 6               ฉันรู้สึกมั่นใจในทักษะของตัวเอง
# 7                         งานนี้ท้าทายแต่ก็สนุก
# 8                      พวกเขาพึงพอใจกับผลการสอบ
# 9                  กาแฟแก้วนี้ช่วยให้ฉันตื่นตัว
# 10           บรรยากาศร้านนี้เงียบสงบและผ่อนคลาย
# 11              บทเรียนนี้ยาก แต่เธอตั้งใจเรียน
# 12            หนังสือเล่มนี้ให้แรงบันดาลใจดีมาก
# 13                        อาหารมื้อนี้อร่อยสุดๆ
# 14                  เขาตื่นเต้นกับโอกาสครั้งนี้
# 15             การเดินทางครั้งนี้สนุกและน่าจดจำ
# 16     ฉันรู้สึกอบอุ่นใจเมื่อได้อยู่กับครอบครัว
# 17                 ฉันผิดหวังกับคุณภาพสินค้านี้
# 18            เขาช่วยฉันแก้ปัญหาได้อย่างรวดเร็ว
# 19                 ฉันตื่นเต้นที่จะเริ่มงานใหม่
# 20        หล่อนรู้สึกเสียใจที่ไม่สามารถไปงานได้
# 21          ฉันมีความหวังว่าวันพรุ่งนี้จะดีขึ้น
# 22                    ฉันเบื่อดูโทรทัศน์ทั้งวัน
# 23           เขารู้สึกผิดหวังเมื่อแพ้การแข่งขัน
# 24     วันนี้ฉันรู้สึกเฉยๆ ไม่มีอะไรเปลี่ยนแปลง
# 25                    ฉันชื่นชมผลงานศิลปะนี้มาก
# 26                       วันนี้อากาศดีและสดชื่น
# 27                  ฉันเบื่อชีวิตประจำวันแบบนี้
# 28                        ฉันกลัวว่าจะทำผิดพลาด
# 29                    ฉันไม่สามารถทนเสียงดังได้
# 30                 คำชมของคุณทำให้ฉันยิ้มไม่หุบ
# 31                    ฉันเกลียดการจราจรที่แออัด
# 32                ฉันรู้สึกเซ็งเมื่อฝนตกทั้งวัน
# 33            เพื่อนร่วมงานของฉันช่วยเหลือดีมาก
# 34               เขาทำงานหนักและได้ผลลัพธ์ที่ดี
# 35               เราภูมิใจในความสำเร็จของตัวเอง
# 36     ฉันไม่แน่ใจว่าตัวเลือกนี้ดีที่สุดหรือไม่
# 37                   ฉันรู้สึกผิดที่ลืมวันสำคัญ
# 38                 ฉันไม่พอใจกับการจัดการของทีม
# 39      ฉันไม่แน่ใจเกี่ยวกับการตัดสินใจครั้งนี้
# 40           การประชุมวันนี้น่าเบื่อและเสียเวลา
# 41                        ฉันกลัวว่าจะถูกปฏิเสธ
# 42                เราดีใจที่ได้ช่วยเหลือผู้อื่น
# 43  การออกกำลังกายทำให้ฉันรู้สึกกระปรี้กระเปร่า
# 44              ฉันรู้สึกแย่ที่ทำให้คนอื่นลำบาก
# 45                       ฉันเบื่อกับการรอคอยนาน
# 46                   ฉันหงุดหงิดเมื่อสิ่งของหาย
# 47             หนังเรื่องนี้น่าเบื่อและยืดเยื้อ
# 48                ฉันรู้สึกเครียดกับกำหนดส่งงาน
# 49                 ฉันรู้สึกกังวลเกี่ยวกับอนาคต
#
#                                           coreference  sbert_score  result
# 0   เมื่อพิจารณาตัวฉันแล้ว ฉันมีความสุขมากที่ได้พบ...       0.9659  ✅ Pass
# 1   เมื่อพิจารณาฉันแล้ว ฉันตื่นเต้นกับการเดินทางไป...       0.9571  ✅ Pass
# 2    เมื่อพิจารณาฉันแล้ว ฉันไม่พอใจกับบริการที่ได้รับ       0.9484  ✅ Pass
# 3    เมื่อพิจารณาตัวฉันแล้ว ฉันรู้สึกเหนื่อยและหมดแรง       0.9515  ✅ Pass
# 4        เมื่อพิจารณาเพลงนี้แล้ว มันทำให้ฉันรู้สึกสงบ       0.9498  ✅ Pass
# 5   เมื่อพิจารณาอาหารจานนี้แล้ว ฉันไม่ชอบกลิ่นอาหา...       0.9673  ✅ Pass
# 6   เมื่อพิจารณาทักษะของตัวเองแล้ว ฉันรู้สึกมั่นใจ...       0.9549  ✅ Pass
# 7           เมื่อพิจารณางานนี้แล้ว มันท้าทายแต่ก็สนุก       0.9434  ✅ Pass
# 8     เมื่อพิจารณาพวกเขาแล้ว พวกเขาพึงพอใจกับผลการสอบ       0.9541  ✅ Pass
# 9    เมื่อพิจารณากาแฟแก้วนี้แล้ว มันช่วยให้ฉันตื่นตัว       0.9684  ✅ Pass
# 10  เมื่อพิจารณาบรรยากาศร้านนี้แล้ว มันเงียบสงบและ...       0.9384  ✅ Pass
# 11  เมื่อพิจารณาบทเรียนนี้แล้ว มันยาก แต่เธอตั้งใจ...       0.9727  ✅ Pass
# 12  เมื่อพิจารณาหนังสือเล่มนี้แล้ว มันให้แรงบันดาล...       0.9568  ✅ Pass
# 13          เมื่อพิจารณาอาหารมื้อนี้แล้ว มันอร่อยสุดๆ       0.9322  ✅ Pass
# 14    เมื่อพิจารณาเขาแล้ว เขาตื่นเต้นกับโอกาสครั้งนี้       0.9502  ✅ Pass
# 15  เมื่อพิจารณาการเดินทางครั้งนี้แล้ว มันสนุกและน...       0.9549  ✅ Pass
# 16  เมื่อพิจารณาฉันแล้ว ฉันรู้สึกอบอุ่นใจเมื่อได้อ...       0.9583  ✅ Pass
# 17  เมื่อพิจารณาคุณภาพสินค้านี้แล้ว ฉันผิดหวังกับค...       0.9572  ✅ Pass
# 18  เมื่อพิจารณาเขาแล้ว เขาช่วยฉันแก้ปัญหาได้อย่าง...       0.9406  ✅ Pass
# 19  เมื่อพิจารณาตัวฉันแล้ว ฉันตื่นเต้นที่จะเริ่มงา...       0.9367  ✅ Pass
# 20  เมื่อพิจารณาหล่อนแล้ว หล่อนรู้สึกเสียใจที่ไม่ส...       0.9645  ✅ Pass
# 21  เมื่อพิจารณาฉันแล้ว ฉันมีความหวังว่าวันพรุ่งนี...       0.9509  ✅ Pass
# 22   เมื่อพิจารณาตัวฉันแล้ว ฉันเบื่อดูโทรทัศน์ทั้งวัน       0.9524  ✅ Pass
# 23  เมื่อพิจารณาเขาแล้ว เขารู้สึกผิดหวังเมื่อแพ้กา...       0.9611  ✅ Pass
# 24  เมื่อพิจารณาวันนี้แล้ว ฉันรู้สึกเฉยๆ ไม่มีอะไร...       0.9502  ✅ Pass
# 25      เมื่อพิจารณาฉันแล้ว ฉันชื่นชมผลงานศิลปะนี้มาก       0.9654  ✅ Pass
# 26            เมื่อพิจารณาวันนี้แล้ว อากาศดีและสดชื่น       0.9268  ✅ Pass
# 27  เมื่อพิจารณาชีวิตประจำวันแบบนี้แล้ว ฉันเบื่อชี...       0.9553  ✅ Pass
# 28       เมื่อพิจารณาตัวฉันแล้ว ฉันกลัวว่าจะทำผิดพลาด       0.9403  ✅ Pass
# 29   เมื่อพิจารณาตัวฉันแล้ว ฉันไม่สามารถทนเสียงดังได้       0.9311  ✅ Pass
# 30   เมื่อพิจารณาคำชมของคุณแล้ว มันทำให้ฉันยิ้มไม่หุบ       0.9208  ✅ Pass
# 31   เมื่อพิจารณาตัวฉันแล้ว ฉันเกลียดการจราจรที่แออัด       0.9583  ✅ Pass
# 32  เมื่อพิจารณาฉันแล้ว ฉันรู้สึกเซ็งเมื่อฝนตกทั้งวัน       0.9648  ✅ Pass
# 33  เมื่อพิจารณาเพื่อนร่วมงานของฉันแล้ว เขาช่วยเหล...       0.8978  ✅ Pass
# 34  เมื่อพิจารณาเขาแล้ว เขาทำงานหนักและได้ผลลัพธ์ท...       0.9434  ✅ Pass
# 35  เมื่อพิจารณาเราตัวเองแล้ว เราภูมิใจในความสำเร็...       0.9357  ✅ Pass
# 36  เมื่อพิจารณาตัวเลือกนี้แล้ว ฉันไม่แน่ใจว่ามันด...       0.9579  ✅ Pass
# 37   เมื่อพิจารณาตนเองแล้ว ฉันรู้สึกผิดที่ลืมวันสำคัญ       0.9618  ✅ Pass
# 38   เมื่อพิจารณาฉันแล้ว ฉันไม่พอใจกับการจัดการของทีม       0.9621  ✅ Pass
# 39  เมื่อพิจารณาการตัดสินใจครั้งนี้แล้ว ฉันไม่แน่ใ...       0.9664  ✅ Pass
# 40  เมื่อพิจารณาการประชุมวันนี้แล้ว มันน่าเบื่อและ...       0.9440  ✅ Pass
# 41       เมื่อพิจารณาตัวฉันแล้ว ฉันกลัวว่าจะถูกปฏิเสธ       0.9359  ✅ Pass
# 42  เมื่อพิจารณาเราที่ได้ช่วยเหลือผู้อื่นแล้ว เราด...       0.9399  ✅ Pass
# 43  เมื่อพิจารณาการออกกำลังกายแล้ว มันทำให้ฉันรู้ส...       0.9714  ✅ Pass
# 44  เมื่อพิจารณาฉันแล้ว ฉันรู้สึกแย่ที่ทำให้คนอื่น...       0.9504  ✅ Pass
# 45         เมื่อพิจารณาฉันแล้ว ฉันเบื่อกับการรอคอยนาน       0.9518  ✅ Pass
# 46     เมื่อพิจารณาฉันแล้ว ฉันหงุดหงิดเมื่อสิ่งของหาย       0.9379  ✅ Pass
# 47  เมื่อพิจารณาหนังเรื่องนี้แล้ว มันน่าเบื่อและยื...       0.9343  ✅ Pass
# 48  เมื่อพิจารณาฉันแล้ว ฉันรู้สึกเครียดกับกำหนดส่งงาน       0.9613  ✅ Pass
# 49  เมื่อพิจารณาตัวฉันเองแล้ว ฉันรู้สึกกังวลเกี่ยว...       0.9414  ✅ Pass

# %% [markdown]
# ##vocab

# %%
PROMPT_VOCAB = """You are an expert bilingual linguist proficient in English and Thai.
Your task is to add exactly one word to the given Thai sentence that slightly enriches or clarifies the meaning without changing its overall semantics or tone.
Context:
 This exercise focuses on vocabulary enhancement while maintaining naturalness and meaning.
 The additional word should fit smoothly into the sentence, adding nuance, specificity, or mild emphasis — not altering the intent.
 Avoid inserting random intensifiers or unrelated words.
The output must remain grammatically and semantically coherent. Do not mix between languages.
The output must remain entirely in Thai and should sound natural to a native speaker.


References (Examples):
 English examples of this modification:
“I’m so tired” to “I’m so really tired”


“I’m not sure what to do with my weekend” to “I’m not sure what to do with my available weekend”
“I’m so stressed out about my financial situation” to “I’m so stressed out about my current financial situation”


Thai examples:
“ฉันเหนื่อยมาก” to “ฉันเหนื่อยมากจริงๆ”


“ฉันชอบวันหยุดนี้” to “ฉันชอบวันหยุดพิเศษนี้”


“เขาทำงานหนัก” to “เขาทำงานหนักมาก”


Thai sentence: "{}"
"""


def gpt_vocab(sentence: str) -> str:
    prompt = PROMPT_VOCAB.format(sentence)
    response = client.chat.completions.create(
        model="gpt-4o-mini",
        messages=[{"role": "user", "content": prompt}],
        temperature=0.3,
    )
    result = response.choices[0].message.content.strip()
    # remove leading/trailing quotes if present
    if result.startswith('"') and result.endswith('"'):
        result = result[1:-1]
    if result.startswith("'") and result.endswith("'"):
        result = result[1:-1]
    return result.strip()


def sbert_similarity(model, sent1, sent2):
    emb1 = model.encode(sent1, convert_to_tensor=True)
    emb2 = model.encode(sent2, convert_to_tensor=True)
    score = util.cos_sim(emb1, emb2)
    return float(score.item())


if __name__ == "__main__":
    df = pd.read_csv(INPUT_CSV)
    model = SentenceTransformer('paraphrase-multilingual-MiniLM-L12-v2')

    results = []
    for s in tqdm(df['original'], desc="Processing"):
        try:
            vocab = gpt_vocab(s)
            score = sbert_similarity(model, s, vocab)
            passed = "✅ Pass" if score >= SBERT_THRESHOLD else "❌ Fail"
            results.append({
                "original": s,
                "vocab": vocab,
                "sbert_score": round(score, 4),
                "result": passed
            })
        except Exception as e:
            results.append({
                "original": s,
                "vocab": None,
                "sbert_score": None,
                "result": f"Error: {e}"
            })

    out_df = pd.DataFrame(results)
    out_df.to_csv(OUTPUT_CSV, index=False, encoding='utf-8-sig')
    print(out_df)
# Out:
# Processing: 100%|██████████| 50/50 [00:43<00:00,  1.15it/s]
#                                        original  \
# 0             ฉันมีความสุขมากที่ได้พบเพื่อนใหม่
# 1          ฉันตื่นเต้นกับการเดินทางไปต่างประเทศ
# 2                  ฉันไม่พอใจกับบริการที่ได้รับ
# 3                     ฉันรู้สึกเหนื่อยและหมดแรง
# 4                      เพลงนี้ทำให้ฉันรู้สึกสงบ
# 5                     ฉันไม่ชอบกลิ่นอาหารจานนี้
# 6               ฉันรู้สึกมั่นใจในทักษะของตัวเอง
# 7                         งานนี้ท้าทายแต่ก็สนุก
# 8                      พวกเขาพึงพอใจกับผลการสอบ
# 9                  กาแฟแก้วนี้ช่วยให้ฉันตื่นตัว
# 10           บรรยากาศร้านนี้เงียบสงบและผ่อนคลาย
# 11              บทเรียนนี้ยาก แต่เธอตั้งใจเรียน
# 12            หนังสือเล่มนี้ให้แรงบันดาลใจดีมาก
# 13                        อาหารมื้อนี้อร่อยสุดๆ
# 14                  เขาตื่นเต้นกับโอกาสครั้งนี้
# 15             การเดินทางครั้งนี้สนุกและน่าจดจำ
# 16     ฉันรู้สึกอบอุ่นใจเมื่อได้อยู่กับครอบครัว
# 17                 ฉันผิดหวังกับคุณภาพสินค้านี้
# 18            เขาช่วยฉันแก้ปัญหาได้อย่างรวดเร็ว
# 19                 ฉันตื่นเต้นที่จะเริ่มงานใหม่
# 20        หล่อนรู้สึกเสียใจที่ไม่สามารถไปงานได้
# 21          ฉันมีความหวังว่าวันพรุ่งนี้จะดีขึ้น
# 22                    ฉันเบื่อดูโทรทัศน์ทั้งวัน
# 23           เขารู้สึกผิดหวังเมื่อแพ้การแข่งขัน
# 24     วันนี้ฉันรู้สึกเฉยๆ ไม่มีอะไรเปลี่ยนแปลง
# 25                    ฉันชื่นชมผลงานศิลปะนี้มาก
# 26                       วันนี้อากาศดีและสดชื่น
# 27                  ฉันเบื่อชีวิตประจำวันแบบนี้
# 28                        ฉันกลัวว่าจะทำผิดพลาด
# 29                    ฉันไม่สามารถทนเสียงดังได้
# 30                 คำชมของคุณทำให้ฉันยิ้มไม่หุบ
# 31                    ฉันเกลียดการจราจรที่แออัด
# 32                ฉันรู้สึกเซ็งเมื่อฝนตกทั้งวัน
# 33            เพื่อนร่วมงานของฉันช่วยเหลือดีมาก
# 34               เขาทำงานหนักและได้ผลลัพธ์ที่ดี
# 35               เราภูมิใจในความสำเร็จของตัวเอง
# 36     ฉันไม่แน่ใจว่าตัวเลือกนี้ดีที่สุดหรือไม่
# 37                   ฉันรู้สึกผิดที่ลืมวันสำคัญ
# 38                 ฉันไม่พอใจกับการจัดการของทีม
# 39      ฉันไม่แน่ใจเกี่ยวกับการตัดสินใจครั้งนี้
# 40           การประชุมวันนี้น่าเบื่อและเสียเวลา
# 41                        ฉันกลัวว่าจะถูกปฏิเสธ
# 42                เราดีใจที่ได้ช่วยเหลือผู้อื่น
# 43  การออกกำลังกายทำให้ฉันรู้สึกกระปรี้กระเปร่า
# 44              ฉันรู้สึกแย่ที่ทำให้คนอื่นลำบาก
# 45                       ฉันเบื่อกับการรอคอยนาน
# 46                   ฉันหงุดหงิดเมื่อสิ่งของหาย
# 47             หนังเรื่องนี้น่าเบื่อและยืดเยื้อ
# 48                ฉันรู้สึกเครียดกับกำหนดส่งงาน
# 49                 ฉันรู้สึกกังวลเกี่ยวกับอนาคต
#
#                                                 vocab  sbert_score  result
# 0             ฉันมีความสุขมากจริงๆ ที่ได้พบเพื่อนใหม่       0.9865  ✅ Pass
# 1        ฉันตื่นเต้นกับการเดินทางไปต่างประเทศครั้งนี้       0.9796  ✅ Pass
# 2                     ฉันไม่พอใจกับบริการที่ได้รับเลย       0.9947  ✅ Pass
# 3                        ฉันรู้สึกเหนื่อยและหมดแรงมาก       0.9924  ✅ Pass
# 4                         เพลงนี้ทำให้ฉันรู้สึกสงบมาก       0.9836  ✅ Pass
# 5                        ฉันไม่ชอบกลิ่นอาหารจานนี้เลย       0.9735  ✅ Pass
# 6                  ฉันรู้สึกมั่นใจในทักษะของตัวเองมาก       0.9733  ✅ Pass
# 7                            งานนี้ท้าทายแต่ก็สนุกมาก       0.9836  ✅ Pass
# 8                      พวกเขาพึงพอใจกับผลการสอบล่าสุด       0.9155  ✅ Pass
# 9                    กาแฟแก้วนี้ช่วยให้ฉันตื่นตัวขึ้น       0.9985  ✅ Pass
# 10              บรรยากาศร้านนี้เงียบสงบและผ่อนคลายมาก       0.9889  ✅ Pass
# 11               บทเรียนนี้ยาก แต่เธอตั้งใจเรียนจริงๆ       0.9818  ✅ Pass
# 12               หนังสือเล่มนี้ให้แรงบันดาลใจที่ดีมาก       0.9956  ✅ Pass
# 13                           อาหารมื้อนี้อร่อยมากสุดๆ       0.9963  ✅ Pass
# 14                   เขาตื่นเต้นกับโอกาสพิเศษครั้งนี้       0.9736  ✅ Pass
# 15                การเดินทางครั้งนี้สนุกและน่าจดจำมาก       0.9928  ✅ Pass
# 16     ฉันรู้สึกอบอุ่นใจเมื่อได้อยู่กับครอบครัวที่รัก       0.9785  ✅ Pass
# 17                    ฉันผิดหวังกับคุณภาพสินค้านี้มาก       0.9842  ✅ Pass
# 18               เขาช่วยฉันแก้ปัญหาได้อย่างรวดเร็วมาก       0.9809  ✅ Pass
# 19              ฉันตื่นเต้นที่จะเริ่มงานใหม่เร็วๆ นี้       0.9638  ✅ Pass
# 20      หล่อนรู้สึกเสียใจอย่างมากที่ไม่สามารถไปงานได้       0.9646  ✅ Pass
# 21        ฉันมีความหวังว่าวันพรุ่งนี้จะดีขึ้นกว่าเดิม       0.9905  ✅ Pass
# 22                     ฉันเบื่อดูโทรทัศน์ทั้งวันจริงๆ       0.9767  ✅ Pass
# 23              เขารู้สึกผิดหวังมากเมื่อแพ้การแข่งขัน       0.9886  ✅ Pass
# 24        วันนี้ฉันรู้สึกเฉยๆ ไม่มีอะไรเปลี่ยนแปลงเลย       0.9968  ✅ Pass
# 25                     ฉันชื่นชมผลงานศิลปะนี้จริงๆมาก       0.9916  ✅ Pass
# 26                          วันนี้อากาศดีและสดชื่นมาก       0.9944  ✅ Pass
# 27                     ฉันเบื่อชีวิตประจำวันแบบนี้มาก       0.9854  ✅ Pass
# 28                          ฉันกลัวว่าจะทำผิดพลาดใหญ่       0.9629  ✅ Pass
# 29                       ฉันไม่สามารถทนเสียงดังได้เลย       0.9981  ✅ Pass
# 30                  คำชมของคุณทำให้ฉันยิ้มอย่างไม่หุบ       0.9950  ✅ Pass
# 31                       ฉันเกลียดการจราจรที่แออัดมาก       0.9878  ✅ Pass
# 32                  ฉันรู้สึกเซ็งเมื่อฝนตกหนักทั้งวัน       0.9931  ✅ Pass
# 33             เพื่อนร่วมงานของฉันช่วยเหลือดีมากจริงๆ       0.9843  ✅ Pass
# 34                  เขาทำงานหนักและได้ผลลัพธ์ที่ดีมาก       0.9853  ✅ Pass
# 35             เราภูมิใจในความสำเร็จที่สำคัญของตัวเอง       0.9836  ✅ Pass
# 36     ฉันไม่แน่ใจว่าตัวเลือกนี้ดีที่สุดจริงๆ หรือไม่       0.9902  ✅ Pass
# 37                      ฉันรู้สึกผิดที่ลืมวันสำคัญนี้       0.9849  ✅ Pass
# 38                    ฉันไม่พอใจกับการจัดการที่ของทีม       0.9542  ✅ Pass
# 39       ฉันไม่แน่ใจเกี่ยวกับการตัดสินใจสำคัญครั้งนี้       0.9748  ✅ Pass
# 40         การประชุมวันนี้น่าเบื่อและเสียเวลาอย่างมาก       0.9736  ✅ Pass
# 41                   ฉันกลัวว่าจะถูกปฏิเสธอย่างรุนแรง       0.9605  ✅ Pass
# 42                   เราดีใจที่ได้ช่วยเหลือผู้อื่นมาก       0.9796  ✅ Pass
# 43  การออกกำลังกายทำให้ฉันรู้สึกกระปรี้กระเปร่ามาก...       0.9829  ✅ Pass
# 44                 ฉันรู้สึกแย่ที่ทำให้คนอื่นลำบากมาก       0.9905  ✅ Pass
# 45                          ฉันเบื่อกับการรอคอยนานมาก       0.9932  ✅ Pass
# 46                    ฉันหงุดหงิดเมื่อสิ่งของสำคัญหาย       0.9316  ✅ Pass
# 47                หนังเรื่องนี้น่าเบื่อและยืดเยื้อมาก       0.9829  ✅ Pass
# 48               ฉันรู้สึกเครียดกับกำหนดส่งงานที่ใกล้       0.9633  ✅ Pass
# 49           ฉันรู้สึกกังวลเกี่ยวกับอนาคตที่ไม่แน่นอน       0.9734  ✅ Pass

# %% [markdown]
# ##negation

# %%
PROMPT_NEGATION = """You are an expert bilingual linguist proficient in English and Thai.
Your task is to negate the given Thai sentence while preserving its original semantic meaning and grammatical naturalness.
Context:
Negation involves transforming a statement into a double negative form without changing its core meaning.
The output must remain grammatically and semantically coherent. Do not mix between languages.
The output must remain entirely in Thai and should sound natural to a native speaker.
Avoid literal translations of “not” — instead, use natural Thai negation patterns such as “ไม่”, “ไม่ได้”, or “ไม่มี” depending on the sentence structure.
References (Examples):
 English examples of similar modifications:
“I’m so tired” to “I’m so not energetic”


“I’m really hungry” to “I’m really not full”


“I’m not sure if I can make it to the event” to “I’m unsure if I can make it to the event”


Thai examples could be:
“ฉันเหนื่อยมาก” to “ฉันไม่ค่อยมีพลัง”


“วันนี้อากาศดี” to “วันนี้อากาศไม่แย่”


“เธอเข้าใจบทเรียนนี้ดี” to “เธอไม่สับสนกับบทเรียนนี้”
Thai sentence: "{}"


"""


def gpt_negation(sentence: str) -> str:
    prompt = PROMPT_NEGATION.format(sentence)
    response = client.chat.completions.create(
        model="gpt-4o-mini",
        messages=[{"role": "user", "content": prompt}],
        temperature=0.3,
    )
    result = response.choices[0].message.content.strip()
    # remove leading/trailing quotes if present
    if result.startswith('"') and result.endswith('"'):
        result = result[1:-1]
    if result.startswith("'") and result.endswith("'"):
        result = result[1:-1]
    return result.strip()


def sbert_similarity(model, sent1, sent2):
    emb1 = model.encode(sent1, convert_to_tensor=True)
    emb2 = model.encode(sent2, convert_to_tensor=True)
    score = util.cos_sim(emb1, emb2)
    return float(score.item())

if __name__ == "__main__":
    df = pd.read_csv(INPUT_CSV)
    model = SentenceTransformer('paraphrase-multilingual-MiniLM-L12-v2')

    results = []
    for s in tqdm(df['original'], desc="Processing"):
        try:
            negated = gpt_negation(s)
            score = sbert_similarity(model, s, negated)
            passed = "✅ Pass" if score >= SBERT_THRESHOLD else "❌ Fail"
            results.append({
                "original": s,
                "negated": negated,
                "sbert_score": round(score, 4),
                "result": passed
            })
        except Exception as e:
            results.append({
                "original": s,
                "negated": None,
                "sbert_score": None,
                "result": f"Error: {e}"
            })

    out_df = pd.DataFrame(results)
    out_df.to_csv(OUTPUT_CSV, index=False, encoding='utf-8-sig')
    print(out_df)
# Out:
# Processing: 100%|██████████| 50/50 [00:49<00:00,  1.01it/s]
#                                        original  \
# 0             ฉันมีความสุขมากที่ได้พบเพื่อนใหม่
# 1          ฉันตื่นเต้นกับการเดินทางไปต่างประเทศ
# 2                  ฉันไม่พอใจกับบริการที่ได้รับ
# 3                     ฉันรู้สึกเหนื่อยและหมดแรง
# 4                      เพลงนี้ทำให้ฉันรู้สึกสงบ
# 5                     ฉันไม่ชอบกลิ่นอาหารจานนี้
# 6               ฉันรู้สึกมั่นใจในทักษะของตัวเอง
# 7                         งานนี้ท้าทายแต่ก็สนุก
# 8                      พวกเขาพึงพอใจกับผลการสอบ
# 9                  กาแฟแก้วนี้ช่วยให้ฉันตื่นตัว
# 10           บรรยากาศร้านนี้เงียบสงบและผ่อนคลาย
# 11              บทเรียนนี้ยาก แต่เธอตั้งใจเรียน
# 12            หนังสือเล่มนี้ให้แรงบันดาลใจดีมาก
# 13                        อาหารมื้อนี้อร่อยสุดๆ
# 14                  เขาตื่นเต้นกับโอกาสครั้งนี้
# 15             การเดินทางครั้งนี้สนุกและน่าจดจำ
# 16     ฉันรู้สึกอบอุ่นใจเมื่อได้อยู่กับครอบครัว
# 17                 ฉันผิดหวังกับคุณภาพสินค้านี้
# 18            เขาช่วยฉันแก้ปัญหาได้อย่างรวดเร็ว
# 19                 ฉันตื่นเต้นที่จะเริ่มงานใหม่
# 20        หล่อนรู้สึกเสียใจที่ไม่สามารถไปงานได้
# 21          ฉันมีความหวังว่าวันพรุ่งนี้จะดีขึ้น
# 22                    ฉันเบื่อดูโทรทัศน์ทั้งวัน
# 23           เขารู้สึกผิดหวังเมื่อแพ้การแข่งขัน
# 24     วันนี้ฉันรู้สึกเฉยๆ ไม่มีอะไรเปลี่ยนแปลง
# 25                    ฉันชื่นชมผลงานศิลปะนี้มาก
# 26                       วันนี้อากาศดีและสดชื่น
# 27                  ฉันเบื่อชีวิตประจำวันแบบนี้
# 28                        ฉันกลัวว่าจะทำผิดพลาด
# 29                    ฉันไม่สามารถทนเสียงดังได้
# 30                 คำชมของคุณทำให้ฉันยิ้มไม่หุบ
# 31                    ฉันเกลียดการจราจรที่แออัด
# 32                ฉันรู้สึกเซ็งเมื่อฝนตกทั้งวัน
# 33            เพื่อนร่วมงานของฉันช่วยเหลือดีมาก
# 34               เขาทำงานหนักและได้ผลลัพธ์ที่ดี
# 35               เราภูมิใจในความสำเร็จของตัวเอง
# 36     ฉันไม่แน่ใจว่าตัวเลือกนี้ดีที่สุดหรือไม่
# 37                   ฉันรู้สึกผิดที่ลืมวันสำคัญ
# 38                 ฉันไม่พอใจกับการจัดการของทีม
# 39      ฉันไม่แน่ใจเกี่ยวกับการตัดสินใจครั้งนี้
# 40           การประชุมวันนี้น่าเบื่อและเสียเวลา
# 41                        ฉันกลัวว่าจะถูกปฏิเสธ
# 42                เราดีใจที่ได้ช่วยเหลือผู้อื่น
# 43  การออกกำลังกายทำให้ฉันรู้สึกกระปรี้กระเปร่า
# 44              ฉันรู้สึกแย่ที่ทำให้คนอื่นลำบาก
# 45                       ฉันเบื่อกับการรอคอยนาน
# 46                   ฉันหงุดหงิดเมื่อสิ่งของหาย
# 47             หนังเรื่องนี้น่าเบื่อและยืดเยื้อ
# 48                ฉันรู้สึกเครียดกับกำหนดส่งงาน
# 49                 ฉันรู้สึกกังวลเกี่ยวกับอนาคต
#
#                                               negated  sbert_score  result
# 0              ฉันไม่มีความทุกข์เลยที่ได้พบเพื่อนใหม่       0.7456  ❌ Fail
# 1     ฉันไม่รู้สึกเบื่อหน่ายกับการเดินทางไปต่างประเทศ       0.6962  ❌ Fail
# 2                  ฉันไม่ไม่พอใจกับบริการที่ไม่ได้รับ       0.9616  ✅ Pass
# 3                ฉันไม่รู้สึกมีพลังและกระปรี้กระเปร่า       0.5378  ❌ Fail
# 4                     เพลงนี้ทำให้ฉันไม่รู้สึกวุ่นวาย       0.8059  ✅ Pass
# 5   ฉันไม่ชอบกลิ่นอาหารจานนี้" เป็น "ฉันไม่ค่อยชอบ...       0.8282  ✅ Pass
# 6               ฉันไม่รู้สึกไม่มั่นใจในทักษะของตัวเอง       0.7441  ❌ Fail
# 7                            งานนี้ไม่ท้าทายแต่ก็สนุก       0.8603  ✅ Pass
# 8                   พวกเขาไม่รู้สึกไม่พอใจกับผลการสอบ       0.6672  ❌ Fail
# 9                    กาแฟแก้วนี้ไม่ได้ทำให้ฉันง่วงนอน       0.8838  ✅ Pass
# 10              บรรยากาศร้านนี้ไม่วุ่นวายและไม่เครียด       0.8172  ✅ Pass
# 11           บทเรียนนี้ไม่ง่าย แต่เธอไม่ละเลยการเรียน       0.8206  ✅ Pass
# 12            หนังสือเล่มนี้ไม่ให้แรงบันดาลใจไม่ดีเลย       0.7636  ✅ Pass
# 13                            อาหารมื้อนี้ไม่อร่อยเลย       0.6711  ❌ Fail
# 14                  เขาไม่รู้สึกเฉยๆ กับโอกาสครั้งนี้       0.4902  ❌ Fail
# 15     การเดินทางครั้งนี้ไม่ได้น่าเบื่อและไม่ลืมเลือน       0.8253  ✅ Pass
# 16          ฉันไม่รู้สึกหนาวใจเมื่อได้อยู่กับครอบครัว       0.7157  ❌ Fail
# 17                       ฉันไม่พอใจกับคุณภาพสินค้านี้       0.8741  ✅ Pass
# 18                       เขาไม่ทำให้ฉันแก้ปัญหาได้ช้า       0.6487  ❌ Fail
# 19                 ฉันไม่รู้สึกเบื่อที่จะเริ่มงานใหม่       0.6896  ❌ Fail
# 20                      หล่อนรู้สึกดีใจที่ไม่ได้ไปงาน       0.7230  ❌ Fail
# 21          ฉันไม่มีความหวังว่าวันพรุ่งนี้จะไม่ดีขึ้น       0.7514  ✅ Pass
# 22                  ฉันไม่สนุกกับการดูโทรทัศน์ทั้งวัน       0.8931  ✅ Pass
# 23                เขาไม่รู้สึกพอใจกับการแพ้การแข่งขัน       0.8499  ✅ Pass
# 24        วันนี้ฉันไม่รู้สึกตื่นเต้น ไม่มีอะไรแตกต่าง       0.7715  ✅ Pass
# 25               ฉันไม่รู้สึกเฉยชากับผลงานศิลปะนี้เลย       0.7014  ❌ Fail
# 26                วันนี้อากาศไม่แย่และไม่รู้สึกอึดอัด       0.8046  ✅ Pass
# 27                   ฉันไม่สนุกกับชีวิตประจำวันแบบนี้       0.8064  ✅ Pass
# 28                         ฉันไม่มั่นใจว่าจะทำถูกต้อง       0.4969  ❌ Fail
# 29                        ฉันสามารถทนเสียงเงียบไม่ได้       0.7748  ✅ Pass
# 30                   คำชมของคุณทำให้ฉันไม่รู้สึกเศร้า       0.7204  ❌ Fail
# 31                        ฉันไม่ชอบการจราจรที่ไม่โล่ง       0.8679  ✅ Pass
# 32                   ฉันไม่รู้สึกสนุกเมื่อฝนตกทั้งวัน       0.7959  ✅ Pass
# 33            เพื่อนร่วมงานของฉันไม่ช่วยเหลือไม่ดีเลย       0.5305  ❌ Fail
# 34            เขาไม่ได้ทำงานเบาและไม่ได้ผลลัพธ์ที่แย่       0.6235  ❌ Fail
# 35            เราไม่อายที่จะพูดถึงความสำเร็จของตัวเอง       0.7726  ✅ Pass
# 36  ฉันไม่ไม่แน่ใจว่าตัวเลือกนี้ไม่ใช่ตัวเลือกที่ด...       0.9259  ✅ Pass
# 37                  ฉันไม่รู้สึกดีที่จำวันสำคัญไม่ได้       0.7350  ❌ Fail
# 38                    ฉันไม่ไม่พอใจกับการจัดการของทีม       0.9886  ✅ Pass
# 39           ฉันไม่มั่นใจเกี่ยวกับการตัดสินใจครั้งนี้       0.9864  ✅ Pass
# 40            การประชุมวันนี้ไม่สนุกและไม่คุ้มค่าเวลา       0.8208  ✅ Pass
# 41                ฉันไม่มั่นใจว่าจะไม่ได้รับการตอบรับ       0.5112  ❌ Fail
# 42        เราไม่รู้สึกเสียใจที่ไม่ได้ช่วยเหลือผู้อื่น       0.6012  ❌ Fail
# 43             การออกกำลังกายทำให้ฉันไม่รู้สึกเหนื่อย       0.7390  ❌ Fail
# 44                ฉันไม่รู้สึกดีที่ทำให้คนอื่นไม่สบาย       0.7753  ✅ Pass
# 45                         ฉันไม่สนุกกับการรอคอยสั้นๆ       0.8467  ✅ Pass
# 46                     ฉันไม่รู้สึกสงบเมื่อสิ่งของหาย       0.7527  ✅ Pass
# 47                   หนังเรื่องนี้ไม่สนุกและไม่กระชับ       0.7289  ❌ Fail
# 48                 ฉันไม่รู้สึกผ่อนคลายกับกำหนดส่งงาน       0.7174  ❌ Fail
# 49                   ฉันไม่รู้สึกสบายใจเกี่ยวกับอนาคต       0.7924  ✅ Pass

# %% [markdown]
# ##taxonomy

# %%
PROMPT_TAXONOMY = """You are an expert linguist in English and Thai.
Your job is to modify a given Thai sentence by replacing one word with its synonym, while keeping the full semantic meaning and natural tone intact.

Context:

This task focuses on lexical variation in Thai. The goal is to show how synonym substitution can maintain meaning while providing diversity in expression.

The output must remain grammatically and semantically coherent. Do not mix between languages. The output must remain entirely in Thai and should sound natural to a native speaker.

References (Examples):
English examples of similar modifications:
“I’m so tired” to “I’m so exhausted”


“I’m really hungry” to “I’m really starving”


“I’m not sure if I can make it to the event” to “I’m not confident if I can make it to the event”


Thai examples could be:
“ฉันชื่นชมผลงานศิลปะนี้มาก” to “ฉันชื่นชอบผลงานศิลปะนี้มาก”


“วันนี้อากาศดีและสดชื่น” to “วันนี้อากาศดีและแจ่มใส”


“ฉันเบื่อชีวิตประจำวันแบบนี้” to “ฉันเซ็งชีวิตประจำวันแบบนี้”



Thai sentence: "{}"

"""

def gpt_taxonomy(sentence: str) -> str:
    prompt = PROMPT_TAXONOMY.format(sentence)
    response = client.chat.completions.create(
        model="gpt-4o-mini",
        messages=[{"role": "user", "content": prompt}],
        temperature=0.3,
    )
    result = response.choices[0].message.content.strip()
    # remove leading/trailing quotes if present
    if result.startswith('"') and result.endswith('"'):
        result = result[1:-1]
    if result.startswith("'") and result.endswith("'"):
        result = result[1:-1]
    return result.strip()


def sbert_similarity(model, sent1, sent2):
    emb1 = model.encode(sent1, convert_to_tensor=True)
    emb2 = model.encode(sent2, convert_to_tensor=True)
    score = util.cos_sim(emb1, emb2)
    return float(score.item())


if __name__ == "__main__":
    df = pd.read_csv(INPUT_CSV)
    model = SentenceTransformer('paraphrase-multilingual-MiniLM-L12-v2')

    results = []
    for s in tqdm(df['original'], desc="Processing"):
        try:
            taxonomy = gpt_taxonomy(s)
            score = sbert_similarity(model, s, taxonomy)
            passed = "✅ Pass" if score >= SBERT_THRESHOLD else "❌ Fail"
            results.append({
                "original": s,
                "taxonomy": taxonomy,
                "sbert_score": round(score, 4),
                "result": passed
            })
        except Exception as e:
            results.append({
                "original": s,
                "taxonomy": None,
                "sbert_score": None,
                "result": f"Error: {e}"
            })

    out_df = pd.DataFrame(results)
    out_df.to_csv(OUTPUT_CSV, index=False, encoding='utf-8-sig')
    print(out_df)
# Out:
# Processing: 100%|██████████| 50/50 [02:30<00:00,  3.01s/it]
#                                        original  \
# 0             ฉันมีความสุขมากที่ได้พบเพื่อนใหม่
# 1          ฉันตื่นเต้นกับการเดินทางไปต่างประเทศ
# 2                  ฉันไม่พอใจกับบริการที่ได้รับ
# 3                     ฉันรู้สึกเหนื่อยและหมดแรง
# 4                      เพลงนี้ทำให้ฉันรู้สึกสงบ
# 5                     ฉันไม่ชอบกลิ่นอาหารจานนี้
# 6               ฉันรู้สึกมั่นใจในทักษะของตัวเอง
# 7                         งานนี้ท้าทายแต่ก็สนุก
# 8                      พวกเขาพึงพอใจกับผลการสอบ
# 9                  กาแฟแก้วนี้ช่วยให้ฉันตื่นตัว
# 10           บรรยากาศร้านนี้เงียบสงบและผ่อนคลาย
# 11              บทเรียนนี้ยาก แต่เธอตั้งใจเรียน
# 12            หนังสือเล่มนี้ให้แรงบันดาลใจดีมาก
# 13                        อาหารมื้อนี้อร่อยสุดๆ
# 14                  เขาตื่นเต้นกับโอกาสครั้งนี้
# 15             การเดินทางครั้งนี้สนุกและน่าจดจำ
# 16     ฉันรู้สึกอบอุ่นใจเมื่อได้อยู่กับครอบครัว
# 17                 ฉันผิดหวังกับคุณภาพสินค้านี้
# 18            เขาช่วยฉันแก้ปัญหาได้อย่างรวดเร็ว
# 19                 ฉันตื่นเต้นที่จะเริ่มงานใหม่
# 20        หล่อนรู้สึกเสียใจที่ไม่สามารถไปงานได้
# 21          ฉันมีความหวังว่าวันพรุ่งนี้จะดีขึ้น
# 22                    ฉันเบื่อดูโทรทัศน์ทั้งวัน
# 23           เขารู้สึกผิดหวังเมื่อแพ้การแข่งขัน
# 24     วันนี้ฉันรู้สึกเฉยๆ ไม่มีอะไรเปลี่ยนแปลง
# 25                    ฉันชื่นชมผลงานศิลปะนี้มาก
# 26                       วันนี้อากาศดีและสดชื่น
# 27                  ฉันเบื่อชีวิตประจำวันแบบนี้
# 28                        ฉันกลัวว่าจะทำผิดพลาด
# 29                    ฉันไม่สามารถทนเสียงดังได้
# 30                 คำชมของคุณทำให้ฉันยิ้มไม่หุบ
# 31                    ฉันเกลียดการจราจรที่แออัด
# 32                ฉันรู้สึกเซ็งเมื่อฝนตกทั้งวัน
# 33            เพื่อนร่วมงานของฉันช่วยเหลือดีมาก
# 34               เขาทำงานหนักและได้ผลลัพธ์ที่ดี
# 35               เราภูมิใจในความสำเร็จของตัวเอง
# 36     ฉันไม่แน่ใจว่าตัวเลือกนี้ดีที่สุดหรือไม่
# 37                   ฉันรู้สึกผิดที่ลืมวันสำคัญ
# 38                 ฉันไม่พอใจกับการจัดการของทีม
# 39      ฉันไม่แน่ใจเกี่ยวกับการตัดสินใจครั้งนี้
# 40           การประชุมวันนี้น่าเบื่อและเสียเวลา
# 41                        ฉันกลัวว่าจะถูกปฏิเสธ
# 42                เราดีใจที่ได้ช่วยเหลือผู้อื่น
# 43  การออกกำลังกายทำให้ฉันรู้สึกกระปรี้กระเปร่า
# 44              ฉันรู้สึกแย่ที่ทำให้คนอื่นลำบาก
# 45                       ฉันเบื่อกับการรอคอยนาน
# 46                   ฉันหงุดหงิดเมื่อสิ่งของหาย
# 47             หนังเรื่องนี้น่าเบื่อและยืดเยื้อ
# 48                ฉันรู้สึกเครียดกับกำหนดส่งงาน
# 49                 ฉันรู้สึกกังวลเกี่ยวกับอนาคต
#
#                                              taxonomy  sbert_score  result
# 0                  ฉันมีความสุขมากที่ได้เจอเพื่อนใหม่       0.9956  ✅ Pass
# 1                 ฉันตื่นตัวกับการเดินทางไปต่างประเทศ       0.8323  ✅ Pass
# 2                         ฉันไม่ชอบกับบริการที่ได้รับ       0.9057  ✅ Pass
# 3                           ฉันรู้สึกอ่อนล้าและหมดแรง       0.8315  ✅ Pass
# 4                       เพลงนี้ทำให้ฉันรู้สึกเงียบสงบ       0.8739  ✅ Pass
# 5                         ฉันไม่ถูกใจกลิ่นอาหารจานนี้       0.9926  ✅ Pass
# 6                  ฉันรู้สึกเชื่อมั่นในทักษะของตัวเอง       0.9491  ✅ Pass
# 7                         งานนี้ท้าทายแต่ก็เพลิดเพลิน       0.9664  ✅ Pass
# 8                                พวกเขาพอใจในผลการสอบ       0.9674  ✅ Pass
# 9                กาแฟแก้วนี้ช่วยให้ฉันกระปรี้กระเปร่า       0.8965  ✅ Pass
# 10                บรรยากาศร้านนี้เงียบสงัดและผ่อนคลาย       0.9875  ✅ Pass
# 11              บทเรียนนี้ยาก แต่เธอมีความตั้งใจเรียน       0.9803  ✅ Pass
# 12                   หนังสือเล่มนี้ให้แรงกระตุ้นดีมาก       0.9010  ✅ Pass
# 13                              อาหารมื้อนี้อร่อยมากๆ       0.9881  ✅ Pass
# 14                         เขาตื่นตัวกับโอกาสครั้งนี้       0.7775  ✅ Pass
# 15               การเดินทางครั้งนี้สนุกและน่าประทับใจ       0.9768  ✅ Pass
# 16               ฉันรู้สึกอบอุ่นใจเมื่อได้อยู่กับญาติ       0.9013  ✅ Pass
# 17                      ฉันผิดหวังกับมาตรฐานสินค้านี้       0.9431  ✅ Pass
# 18                    เขาช่วยฉันแก้ปัญหาได้อย่างทันที       0.8792  ✅ Pass
# 19                        ฉันตื่นตัวที่จะเริ่มงานใหม่       0.8718  ✅ Pass
# 20             หล่อนรู้สึกเศร้าใจที่ไม่สามารถไปงานได้       0.9129  ✅ Pass
# 21             ฉันมีความคาดหวังว่าวันพรุ่งนี้จะดีขึ้น       0.9643  ✅ Pass
# 22                           ฉันเซ็งดูโทรทัศน์ทั้งวัน       0.8184  ✅ Pass
# 23                  เขารู้สึกท้อแท้เมื่อแพ้การแข่งขัน       0.9641  ✅ Pass
# 24          วันนี้ฉันรู้สึกนิ่งๆ ไม่มีอะไรเปลี่ยนแปลง       0.9581  ✅ Pass
# 25                         ฉันชื่นชอบผลงานศิลปะนี้มาก       0.9896  ✅ Pass
# 26                             วันนี้อากาศดีและแจ่มใส       0.9416  ✅ Pass
# 27                         ฉันเซ็งชีวิตประจำวันแบบนี้       0.8906  ✅ Pass
# 28                           ฉันหวั่นใจว่าจะทำผิดพลาด       0.9431  ✅ Pass
# 29                        ฉันไม่สามารถอดทนเสียงดังได้       0.9832  ✅ Pass
# 30                   คำชื่นชมของคุณทำให้ฉันยิ้มไม่หุบ       0.9467  ✅ Pass
# 31                        ฉันเกลียดการจราจรที่หนาแน่น       0.9871  ✅ Pass
# 32                     ฉันรู้สึกเบื่อเมื่อฝนตกทั้งวัน       0.7721  ✅ Pass
# 33              เพื่อนร่วมงานของฉันช่วยเหลือเยี่ยมมาก       0.9811  ✅ Pass
# 34              เขาทำงานหนักและได้ผลลัพธ์ที่ยอดเยี่ยม       0.9611  ✅ Pass
# 35                  เราภาคภูมิใจในความสำเร็จของตัวเอง       0.9968  ✅ Pass
# 36          ฉันไม่มั่นใจว่าตัวเลือกนี้ดีที่สุดหรือไม่       0.9981  ✅ Pass
# 37                      ฉันรู้สึกเสียใจที่ลืมวันสำคัญ       0.9670  ✅ Pass
# 38                    ฉันไม่พอใจในวิธีการจัดการของทีม       0.9926  ✅ Pass
# 39           ฉันไม่มั่นใจเกี่ยวกับการตัดสินใจครั้งนี้       0.9864  ✅ Pass
# 40               การประชุมวันนี้น่าเบื่อและไม่คุ้มค่า       0.9482  ✅ Pass
# 41   ฉันกลัวว่าจะถูกปฏิเสธ" to "ฉันกลัวว่าจะถูกปฏิเสธ       0.9011  ✅ Pass
# 42                 เรามีความสุขที่ได้ช่วยเหลือผู้อื่น       0.9850  ✅ Pass
# 43                 การออกกำลังกายทำให้ฉันรู้สึกสดชื่น       0.9131  ✅ Pass
# 44                  ฉันรู้สึกไม่ดีที่ทำให้คนอื่นลำบาก       0.9858  ✅ Pass
# 45                              ฉันเซ็งกับการรอคอยนาน       0.9449  ✅ Pass
# 46                            ฉันรำคาญเมื่อสิ่งของหาย       0.9126  ✅ Pass
# 47  หนังเรื่องนี้น่าเบื่อและยืดเยื้อ" to "หนังเรื่...       0.8496  ✅ Pass
# 48                   ฉันรู้สึกวิตกกังวลกับกำหนดส่งงาน       0.8368  ✅ Pass
# 49                   ฉันรู้สึกวิตกกังวลเกี่ยวกับอนาคต       0.9927  ✅ Pass

# %% [markdown]
# ##NER

# %%
PROMPT_NER = """You are an expert bilingual linguist proficient in English and Thai.
Your task is to replace the named entity (e.g., person’s name or pronoun) in the given Thai sentence with a different proper name, while keeping the sentence’s meaning and structure natural.
Context:
The goal is to perform a named entity replacement — not translation or paraphrasing.
You should change the reference (such as replacing “ฉัน” or “เขา” with “เจน”, “แจ็ค”, etc.) while ensuring that the sentence remains fluent and semantically intact.
Do not alter verb tense, sentence tone, or polarity.
The output must remain grammatically and semantically coherent. Do not mix between languages.
The output must remain entirely in Thai and should sound natural to a native speaker.


References (Examples):
 English examples of the same modification:
“I’m so tired” to “Jane is so tired”


“I’m really hungry” to “Jack is really hungry”


“I’m not sure if I can make it to the event” to “Jill is not sure if she can make it to the event”


Thai examples:
“ฉันเหนื่อยมาก” to “เจนเหนื่อยมาก”


“ผมหิวมาก” to “แจ็คหิวมาก”


“ฉันไม่แน่ใจว่าจะไปได้ไหม” to “จิลไม่แน่ใจว่าเธอจะไปได้ไหม”


Thai sentence: "{}"
"""


def gpt_ner(sentence: str) -> str:
    prompt = PROMPT_NER.format(sentence)
    response = client.chat.completions.create(
        model="gpt-4o-mini",
        messages=[{"role": "user", "content": prompt}],
        temperature=0.3,
    )
    result = response.choices[0].message.content.strip()
    # remove leading/trailing quotes if present
    if result.startswith('"') and result.endswith('"'):
        result = result[1:-1]
    if result.startswith("'") and result.endswith("'"):
        result = result[1:-1]
    return result.strip()


def sbert_similarity(model, sent1, sent2):
    emb1 = model.encode(sent1, convert_to_tensor=True)
    emb2 = model.encode(sent2, convert_to_tensor=True)
    score = util.cos_sim(emb1, emb2)
    return float(score.item())


if __name__ == "__main__":
    df = pd.read_csv(INPUT_CSV)
    model = SentenceTransformer('paraphrase-multilingual-MiniLM-L12-v2')

    results = []
    for s in tqdm(df['original'], desc="Processing"):
        try:
            ner = gpt_ner(s)
            score = sbert_similarity(model, s, ner)
            passed = "✅ Pass" if score >= SBERT_THRESHOLD else "❌ Fail"
            results.append({
                "original": s,
                "ner": ner,
                "sbert_score": round(score, 4),
                "result": passed
            })
        except Exception as e:
            results.append({
                "original": s,
                "ner": None,
                "sbert_score": None,
                "result": f"Error: {e}"
            })

    out_df = pd.DataFrame(results)
    out_df.to_csv(OUTPUT_CSV, index=False, encoding='utf-8-sig')
    print(out_df)
# Out:
# Processing: 100%|██████████| 50/50 [00:48<00:00,  1.02it/s]
#                                        original  \
# 0             ฉันมีความสุขมากที่ได้พบเพื่อนใหม่
# 1          ฉันตื่นเต้นกับการเดินทางไปต่างประเทศ
# 2                  ฉันไม่พอใจกับบริการที่ได้รับ
# 3                     ฉันรู้สึกเหนื่อยและหมดแรง
# 4                      เพลงนี้ทำให้ฉันรู้สึกสงบ
# 5                     ฉันไม่ชอบกลิ่นอาหารจานนี้
# 6               ฉันรู้สึกมั่นใจในทักษะของตัวเอง
# 7                         งานนี้ท้าทายแต่ก็สนุก
# 8                      พวกเขาพึงพอใจกับผลการสอบ
# 9                  กาแฟแก้วนี้ช่วยให้ฉันตื่นตัว
# 10           บรรยากาศร้านนี้เงียบสงบและผ่อนคลาย
# 11              บทเรียนนี้ยาก แต่เธอตั้งใจเรียน
# 12            หนังสือเล่มนี้ให้แรงบันดาลใจดีมาก
# 13                        อาหารมื้อนี้อร่อยสุดๆ
# 14                  เขาตื่นเต้นกับโอกาสครั้งนี้
# 15             การเดินทางครั้งนี้สนุกและน่าจดจำ
# 16     ฉันรู้สึกอบอุ่นใจเมื่อได้อยู่กับครอบครัว
# 17                 ฉันผิดหวังกับคุณภาพสินค้านี้
# 18            เขาช่วยฉันแก้ปัญหาได้อย่างรวดเร็ว
# 19                 ฉันตื่นเต้นที่จะเริ่มงานใหม่
# 20        หล่อนรู้สึกเสียใจที่ไม่สามารถไปงานได้
# 21          ฉันมีความหวังว่าวันพรุ่งนี้จะดีขึ้น
# 22                    ฉันเบื่อดูโทรทัศน์ทั้งวัน
# 23           เขารู้สึกผิดหวังเมื่อแพ้การแข่งขัน
# 24     วันนี้ฉันรู้สึกเฉยๆ ไม่มีอะไรเปลี่ยนแปลง
# 25                    ฉันชื่นชมผลงานศิลปะนี้มาก
# 26                       วันนี้อากาศดีและสดชื่น
# 27                  ฉันเบื่อชีวิตประจำวันแบบนี้
# 28                        ฉันกลัวว่าจะทำผิดพลาด
# 29                    ฉันไม่สามารถทนเสียงดังได้
# 30                 คำชมของคุณทำให้ฉันยิ้มไม่หุบ
# 31                    ฉันเกลียดการจราจรที่แออัด
# 32                ฉันรู้สึกเซ็งเมื่อฝนตกทั้งวัน
# 33            เพื่อนร่วมงานของฉันช่วยเหลือดีมาก
# 34               เขาทำงานหนักและได้ผลลัพธ์ที่ดี
# 35               เราภูมิใจในความสำเร็จของตัวเอง
# 36     ฉันไม่แน่ใจว่าตัวเลือกนี้ดีที่สุดหรือไม่
# 37                   ฉันรู้สึกผิดที่ลืมวันสำคัญ
# 38                 ฉันไม่พอใจกับการจัดการของทีม
# 39      ฉันไม่แน่ใจเกี่ยวกับการตัดสินใจครั้งนี้
# 40           การประชุมวันนี้น่าเบื่อและเสียเวลา
# 41                        ฉันกลัวว่าจะถูกปฏิเสธ
# 42                เราดีใจที่ได้ช่วยเหลือผู้อื่น
# 43  การออกกำลังกายทำให้ฉันรู้สึกกระปรี้กระเปร่า
# 44              ฉันรู้สึกแย่ที่ทำให้คนอื่นลำบาก
# 45                       ฉันเบื่อกับการรอคอยนาน
# 46                   ฉันหงุดหงิดเมื่อสิ่งของหาย
# 47             หนังเรื่องนี้น่าเบื่อและยืดเยื้อ
# 48                ฉันรู้สึกเครียดกับกำหนดส่งงาน
# 49                 ฉันรู้สึกกังวลเกี่ยวกับอนาคต
#
#                                                   ner  sbert_score  result
# 0                   เจนมีความสุขมากที่ได้พบเพื่อนใหม่       0.8416  ✅ Pass
# 1                เจนตื่นเต้นกับการเดินทางไปต่างประเทศ       0.9313  ✅ Pass
# 2                        เจนไม่พอใจกับบริการที่ได้รับ       0.5789  ❌ Fail
# 3                           เจนรู้สึกเหนื่อยและหมดแรง       0.6989  ❌ Fail
# 4                            เพลงนี้ทำให้เจนรู้สึกสงบ       0.7103  ❌ Fail
# 5                           เจนไม่ชอบกลิ่นอาหารจานนี้       0.7830  ✅ Pass
# 6                     เจนรู้สึกมั่นใจในทักษะของตัวเอง       0.5968  ❌ Fail
# 7   งานนี้ท้าทายแต่ก็สนุก" to "เจนบอกว่างานนี้ท้าท...       0.8150  ✅ Pass
# 8   พวกเขาพึงพอใจกับผลการสอบ" to "พวกเขาพึงพอใจกับ...       0.6959  ❌ Fail
# 9                        กาแฟแก้วนี้ช่วยให้เจนตื่นตัว       0.8636  ✅ Pass
# 10  "บรรยากาศร้านนี้เงียบสงบและผ่อนคลาย" to "บรรยา...       0.5458  ❌ Fail
# 11                    บทเรียนนี้ยาก แต่เจนตั้งใจเรียน       0.8662  ✅ Pass
# 12  หนังสือเล่มนี้ให้แรงบันดาลใจดีมาก" to "เจนบอกว...       0.8666  ✅ Pass
# 13  อาหารมื้อนี้อร่อยสุดๆ" to "เจนบอกว่าอาหารมื้อน...       0.8243  ✅ Pass
# 14                       แจ็คตื่นเต้นกับโอกาสครั้งนี้       0.6914  ❌ Fail
# 15  การเดินทางครั้งนี้สนุกและน่าจดจำ" to "การเดินท...       0.7629  ✅ Pass
# 16           เจนรู้สึกอบอุ่นใจเมื่อได้อยู่กับครอบครัว       0.7083  ❌ Fail
# 17                       เจนผิดหวังกับคุณภาพสินค้านี้       0.7870  ✅ Pass
# 18                  เขาช่วยเจนแก้ปัญหาได้อย่างรวดเร็ว       0.7829  ✅ Pass
# 19                       เจนตื่นเต้นที่จะเริ่มงานใหม่       0.8991  ✅ Pass
# 20                เจนรู้สึกเสียใจที่ไม่สามารถไปงานได้       0.8599  ✅ Pass
# 21                เจนมีความหวังว่าวันพรุ่งนี้จะดีขึ้น       0.8577  ✅ Pass
# 22                          เจนเบื่อดูโทรทัศน์ทั้งวัน       0.7876  ✅ Pass
# 23                แจ็ครู้สึกผิดหวังเมื่อแพ้การแข่งขัน       0.7528  ✅ Pass
# 24           วันนี้เจนรู้สึกเฉยๆ ไม่มีอะไรเปลี่ยนแปลง       0.7745  ✅ Pass
# 25                          เจนชื่นชมผลงานศิลปะนี้มาก       0.8252  ✅ Pass
# 26  วันนี้อากาศดีและสดชื่น" to "วันนี้เจนรู้สึกว่า...       0.7743  ✅ Pass
# 27                        เจนเบื่อชีวิตประจำวันแบบนี้       0.6642  ❌ Fail
# 28                              เจนกลัวว่าจะทำผิดพลาด       0.7065  ❌ Fail
# 29                          เจนไม่สามารถทนเสียงดังได้       0.7729  ✅ Pass
# 30                       คำชมของคุณทำให้เจนยิ้มไม่หุบ       0.7127  ❌ Fail
# 31                          เจนเกลียดการจราจรที่แออัด       0.8936  ✅ Pass
# 32                      เจนรู้สึกเซ็งเมื่อฝนตกทั้งวัน       0.7533  ✅ Pass
# 33                  เพื่อนร่วมงานของเจนช่วยเหลือดีมาก       0.7565  ✅ Pass
# 34                    แจ็คทำงานหนักและได้ผลลัพธ์ที่ดี       0.7097  ❌ Fail
# 35                     เจนภูมิใจในความสำเร็จของตัวเอง       0.6994  ❌ Fail
# 36           เจนไม่แน่ใจว่าตัวเลือกนี้ดีที่สุดหรือไม่       0.7082  ❌ Fail
# 37                         เจนรู้สึกผิดที่ลืมวันสำคัญ       0.7777  ✅ Pass
# 38                       เจนไม่พอใจกับการจัดการของทีม       0.6732  ❌ Fail
# 39            เจนไม่แน่ใจเกี่ยวกับการตัดสินใจครั้งนี้       0.6835  ❌ Fail
# 40  การประชุมวันนี้น่าเบื่อและเสียเวลา" to "การประ...       0.8521  ✅ Pass
# 41                              เจนกลัวว่าจะถูกปฏิเสธ       0.7284  ❌ Fail
# 42                      เจนดีใจที่ได้ช่วยเหลือผู้อื่น       0.8043  ✅ Pass
# 43        การออกกำลังกายทำให้เจนรู้สึกกระปรี้กระเปร่า       0.7084  ❌ Fail
# 44                    เจนรู้สึกแย่ที่ทำให้คนอื่นลำบาก       0.6437  ❌ Fail
# 45                             เจนเบื่อกับการรอคอยนาน       0.7864  ✅ Pass
# 46                         เจนหงุดหงิดเมื่อสิ่งของหาย       0.7709  ✅ Pass
# 47  "หนังเรื่องนี้น่าเบื่อและยืดเยื้อ" to "หนังเรื...       0.5345  ❌ Fail
# 48                      เจนรู้สึกเครียดกับกำหนดส่งงาน       0.6984  ❌ Fail
# 49                       เจนรู้สึกกังวลเกี่ยวกับอนาคต       0.7524  ✅ Pass

# %% [markdown]
# ##robustness

# %%
import random
import string
import math

class Perturbation:
    """Lightweight offline version of the Perturbation class."""

    def robust(self, text, num=20):
        """
        Create multiple sentences where each sentence has exactly one different word perturbed.
        """
        words = text.split()
        perturbed_sentences = []
        eligible_words = [i for i, word in enumerate(words) if len(word.rstrip(string.punctuation)) >= 2]

        if not eligible_words:
            return [text]

        num = max(1, min(100, num))
        words_to_swap = math.ceil(len(eligible_words) * (num / 100.0))
        words_to_swap = min(words_to_swap, len(eligible_words))
        indices_to_swap = random.sample(eligible_words, words_to_swap)

        for i in indices_to_swap:
            modified = words.copy()
            w = words[i]
            if len(w) > 2:
                j = random.randint(0, len(w) - 2)
                perturbed = w[:j] + w[j+1] + w[j] + w[j+2:]
                modified[i] = perturbed
                perturbed_sentences.append(" ".join(modified))
        return perturbed_sentences

# %%
from sentence_transformers import SentenceTransformer, util
import numpy as np
import pandas as pd

model = SentenceTransformer('paraphrase-multilingual-MiniLM-L12-v2')  # handles Thai

p = Perturbation()

def calculate_robustness(text, model, p, num=20):
    perturbed_sentences = p.robust(text, num)
    original_emb = model.encode(text, convert_to_tensor=True)
    pert_embs = model.encode(perturbed_sentences, convert_to_tensor=True)
    sims = [float(util.cos_sim(original_emb, emb)) for emb in pert_embs]
    robustness_score = np.mean(sims)
    return robustness_score, perturbed_sentences

# %%
# Load your Thai sentences
df = pd.read_csv("/content/s-bert - original.csv")

scores, perturbations = [], []
for text in df["original"]:
    score, pert = calculate_robustness(str(text), model, p)
    scores.append(score)
    perturbations.append(pert)

df["robustness"] = scores
df["perturbations"] = perturbations

# 🧹 Clean up [' '] brackets and quotes
df["perturbations"] = df["perturbations"].apply(lambda x: ", ".join(x) if isinstance(x, list) else str(x))

df.to_excel("robustness_results.xlsx", index=False)
print("✅ Saved to robustness_results.xlsx (clean version)")
# Out:
# ✅ Saved to robustness_results.xlsx (clean version)
