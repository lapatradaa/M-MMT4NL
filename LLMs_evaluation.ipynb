# %% [markdown]
# <a href="https://colab.research.google.com/github/lapatradaa/M-MMT4NL/blob/main/LLMs_evaluation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install sacrebleu bert-score
# !pip install sacrebleu bert-score pythainlp
# Out:
# Requirement already satisfied: sacrebleu in /usr/local/lib/python3.12/dist-packages (2.5.1)
# Requirement already satisfied: bert-score in /usr/local/lib/python3.12/dist-packages (0.3.13)
# Requirement already satisfied: portalocker in /usr/local/lib/python3.12/dist-packages (from sacrebleu) (3.2.0)
# Requirement already satisfied: regex in /usr/local/lib/python3.12/dist-packages (from sacrebleu) (2024.11.6)
# Requirement already satisfied: tabulate>=0.8.9 in /usr/local/lib/python3.12/dist-packages (from sacrebleu) (0.9.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from sacrebleu) (2.0.2)
# Requirement already satisfied: colorama in /usr/local/lib/python3.12/dist-packages (from sacrebleu) (0.4.6)
# Requirement already satisfied: lxml in /usr/local/lib/python3.12/dist-packages (from sacrebleu) (5.4.0)
# Requirement already satisfied: torch>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from bert-score) (2.8.0+cu126)
# Requirement already satisfied: pandas>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from bert-score) (2.2.2)
# Requirement already satisfied: transformers>=3.0.0 in /usr/local/lib/python3.12/dist-packages (from bert-score) (4.55.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from bert-score) (2.32.4)
# Requirement already satisfied: tqdm>=4.31.1 in /usr/local/lib/python3.12/dist-packages (from bert-score) (4.67.1)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from bert-score) (3.10.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.12/dist-packages (from bert-score) (25.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.0.1->bert-score) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.0.1->bert-score) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.0.1->bert-score) (2025.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->bert-score) (3.19.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->bert-score) (4.14.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->bert-score) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->bert-score) (1.13.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->bert-score) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->bert-score) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->bert-score) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->bert-score) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->bert-score) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->bert-score) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->bert-score) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->bert-score) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->bert-score) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->bert-score) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->bert-score) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->bert-score) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->bert-score) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->bert-score) (2.27.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->bert-score) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->bert-score) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->bert-score) (1.11.1.6)
# Requirement already satisfied: triton==3.4.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->bert-score) (3.4.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.34.0 in /usr/local/lib/python3.12/dist-packages (from transformers>=3.0.0->bert-score) (0.34.4)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from transformers>=3.0.0->bert-score) (6.0.2)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.12/dist-packages (from transformers>=3.0.0->bert-score) (0.21.4)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from transformers>=3.0.0->bert-score) (0.6.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->bert-score) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->bert-score) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->bert-score) (4.59.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->bert-score) (1.4.9)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->bert-score) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->bert-score) (3.2.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->bert-score) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->bert-score) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->bert-score) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->bert-score) (2025.8.3)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.34.0->transformers>=3.0.0->bert-score) (1.1.7)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas>=1.0.1->bert-score) (1.17.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=1.0.0->bert-score) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=1.0.0->bert-score) (3.0.2)
# Requirement already satisfied: sacrebleu in /usr/local/lib/python3.12/dist-packages (2.5.1)
# Requirement already satisfied: bert-score in /usr/local/lib/python3.12/dist-packages (0.3.13)
# Collecting pythainlp
#   Downloading pythainlp-5.1.2-py3-none-any.whl.metadata (8.0 kB)
# Requirement already satisfied: portalocker in /usr/local/lib/python3.12/dist-packages (from sacrebleu) (3.2.0)
# Requirement already satisfied: regex in /usr/local/lib/python3.12/dist-packages (from sacrebleu) (2024.11.6)
# Requirement already satisfied: tabulate>=0.8.9 in /usr/local/lib/python3.12/dist-packages (from sacrebleu) (0.9.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from sacrebleu) (2.0.2)
# Requirement already satisfied: colorama in /usr/local/lib/python3.12/dist-packages (from sacrebleu) (0.4.6)
# Requirement already satisfied: lxml in /usr/local/lib/python3.12/dist-packages (from sacrebleu) (5.4.0)
# Requirement already satisfied: torch>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from bert-score) (2.8.0+cu126)
# Requirement already satisfied: pandas>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from bert-score) (2.2.2)
# Requirement already satisfied: transformers>=3.0.0 in /usr/local/lib/python3.12/dist-packages (from bert-score) (4.55.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from bert-score) (2.32.4)
# Requirement already satisfied: tqdm>=4.31.1 in /usr/local/lib/python3.12/dist-packages (from bert-score) (4.67.1)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from bert-score) (3.10.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.12/dist-packages (from bert-score) (25.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.0.1->bert-score) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.0.1->bert-score) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.0.1->bert-score) (2025.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->bert-score) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->bert-score) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->bert-score) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->bert-score) (2025.8.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->bert-score) (3.19.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->bert-score) (4.14.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->bert-score) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->bert-score) (1.13.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->bert-score) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->bert-score) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->bert-score) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->bert-score) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->bert-score) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->bert-score) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->bert-score) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->bert-score) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->bert-score) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->bert-score) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->bert-score) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->bert-score) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->bert-score) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->bert-score) (2.27.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->bert-score) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->bert-score) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->bert-score) (1.11.1.6)
# Requirement already satisfied: triton==3.4.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->bert-score) (3.4.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.34.0 in /usr/local/lib/python3.12/dist-packages (from transformers>=3.0.0->bert-score) (0.34.4)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from transformers>=3.0.0->bert-score) (6.0.2)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.12/dist-packages (from transformers>=3.0.0->bert-score) (0.21.4)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from transformers>=3.0.0->bert-score) (0.6.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->bert-score) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->bert-score) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->bert-score) (4.59.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->bert-score) (1.4.9)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->bert-score) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->bert-score) (3.2.3)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.34.0->transformers>=3.0.0->bert-score) (1.1.7)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas>=1.0.1->bert-score) (1.17.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=1.0.0->bert-score) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=1.0.0->bert-score) (3.0.2)
# Downloading pythainlp-5.1.2-py3-none-any.whl (19.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.3/19.3 MB 28.9 MB/s eta 0:00:00
# Installing collected packages: pythainlp
# Successfully installed pythainlp-5.1.2

# %%
from typing import List
import sacrebleu
from sacrebleu.metrics import BLEU
from bert_score import score as bert_score

# --- Your example sentences ---
references: List[str] = [
    "วันนี้อากาศดีและสดชื่น",
]
candidates: List[str] = [
    "อากาศวันนี้สดชื่นและน่ารื่นรมย์",
]

# =============== BLEU helpers ===============
def bleu_sacrebleu(hyps: List[str], refs: List[str], tokenizer: str = "intl") -> float:
    """
    Use sacreBLEU with 'intl' for multilingual/Thai.
    Returns BLEU score on 0..100 scale.
    """
    bleu = BLEU(tokenize=tokenizer)  # create BLEU scorer
    return bleu.corpus_score(hyps, [refs]).score

def bleu_with_thai_tokenization(hyps: List[str], refs: List[str]) -> float:
    """
    Thai word segmentation to add spaces before BLEU.
    """
    try:
        from pythainlp.tokenize import word_tokenize
    except Exception as e:
        raise RuntimeError("Please `pip install pythainlp` to use Thai tokenization.") from e

    seg = lambda s: " ".join(word_tokenize(s, engine="newmm"))
    hyps_seg = [seg(x) for x in hyps]
    refs_seg = [seg(x) for x in refs]

    bleu = BLEU(tokenize="13a")  # English-style now works after segmentation
    return bleu.corpus_score(hyps_seg, [refs_seg]).score

# =============== BERTScore helper ===============
def bertscore(hyps: List[str], refs: List[str],
              model_type: str = "xlm-roberta-large") -> dict:
    """
    Use a multilingual model for Thai (XLM-R large is a strong default).
    Returns mean Precision/Recall/F1 in 0..1 range.
    """
    P, R, F = bert_score(hyps, refs, model_type=model_type, verbose=False)
    return {
        "P": P.mean().item(),
        "R": R.mean().item(),
        "F1": F.mean().item(),
    }

# =============== Evaluate ===============
print("Pairs:", len(references))

# BLEU (multilingual, no extra tokenization)
bleu_intl = bleu_sacrebleu(candidates, references, tokenizer="intl")
print(f"BLEU (intl tokenizer): {bleu_intl:.2f}")

# BLEU with Thai word segmentation
try:
    bleu_thseg = bleu_with_thai_tokenization(candidates, references)
    print(f"BLEU (with Thai tokenization): {bleu_thseg:.2f}")
except RuntimeError as e:
    print("(Skip tokenized BLEU) ->", e)

# BERTScore (semantic)
b = bertscore(candidates, references, model_type="xlm-roberta-large")
print(f"BERTScore-P: {b['P']:.4f}  BERTScore-R: {b['R']:.4f}  BERTScore-F1: {b['F1']:.4f}")
# Out:
# Pairs: 1
# BLEU (intl tokenizer): 0.00
# BLEU (with Thai tokenization): 15.11
# BERTScore-P: 0.9522  BERTScore-R: 0.9591  BERTScore-F1: 0.9556

# %% [markdown]
# ##################

# %%
# ---- Install (Colab) ----
# !pip -q install sacrebleu bert-score pythainlp pandas openpyxl tqdm

import re
import pandas as pd
from tqdm import tqdm
from typing import List, Tuple
from sacrebleu.metrics import BLEU
from bert_score import score as bert_score

# ====== CONFIG ======
XLSX_PATH = "/MMT4NL_result.xlsx"   # เปลี่ยนเป็นพาธไฟล์ของคุณ (หรืออัปโหลดทาง Colab)
SAVE_PATH = "/content/MMT4NL_result_scored.xlsx"

# %%
# ระบุชื่อคอลัมน์ ถ้าทราบแน่นอน (แนะนำ)
REF_COL = None        # เช่น "reference" หรือ "gold"
HYP_COL = None        # เช่น "candidate" หรือ "prediction"

# ภาษาไทย: ใช้ตัดคำและ tokenizer ที่เหมาะสม
USE_THAI_WORD_SEG = True            # True = ตัดคำไทยก่อนคำนวณ BLEU
BERT_MODEL = "xlm-roberta-large"    # multilingual เหมาะกับไทย
BLEU_TOKENIZER_NOSEG = "intl"       # ถ้าไม่ตัดคำ ใช้ intl
BLEU_TOKENIZER_SEG   = "13a"        # ถ้าตัดคำแล้ว ใช้ 13a

# %%
# ====== Helpers ======
def find_cols(df: pd.DataFrame) -> Tuple[str, str]:
    """เดาชื่อคอลัมน์อัตโนมัติ ถ้าไม่ระบุไว้ใน CONFIG"""
    cols = [c.lower() for c in df.columns]
    ref_candidates = ["reference", "ref", "target", "gold", "ground", "groundtruth", "gt", "answer"]
    hyp_candidates = ["candidate", "hypothesis", "hyp", "prediction", "pred", "output", "system"]
    ref = next((c for c in df.columns if c.lower() in ref_candidates), None)
    hyp = next((c for c in df.columns if c.lower() in hyp_candidates), None)
    if ref is None or hyp is None:
        # ลองเดาจากคำหลัก
        ref = ref or next((c for c in df.columns if re.search(r"ref|gold|answer|target", c, re.I)), None)
        hyp = hyp or next((c for c in df.columns if re.search(r"hyp|cand|pred|out|system", c, re.I)), None)
    if ref is None or hyp is None:
        raise ValueError(
            f"ไม่พบคอลัมน์อ้างอิง/ผลโมเดลในชีตครับ โปรดตั้ง REF_COL/HYP_COL ให้ชัด "
            f"หรือเปลี่ยนชื่อหัวคอลัมน์ให้มีคำว่า reference/candidate (ปัจจุบันมี: {list(df.columns)})"
        )
    return hyp, ref

def thai_segment(texts: List[str]) -> List[str]:
    from pythainlp.tokenize import word_tokenize
    seg = lambda s: " ".join(word_tokenize(str(s), engine="newmm"))
    return [seg(t if isinstance(t, str) else "") for t in texts]

def compute_bleu_per_sentence(hyps: List[str], refs: List[str], use_seg: bool) -> List[float]:
    """
    คำนวณ BLEU แบบประโยคต่อประโยค (sentence-level) พร้อม smoothing
    - ถ้า use_seg=True จะตัดคำไทยก่อน แล้วใช้ tokenizer='13a'
    - ถ้า use_seg=False จะไม่ตัดคำ ใช้ tokenizer='intl'
    """
    if use_seg:
        hyps_proc = thai_segment(hyps)
        refs_proc = thai_segment(refs)
        bleu = BLEU(tokenize=BLEU_TOKENIZER_SEG, smooth_method="exp")
    else:
        hyps_proc, refs_proc = hyps, refs
        bleu = BLEU(tokenize=BLEU_TOKENIZER_NOSEG, smooth_method="exp")

    scores = []
    for h, r in zip(hyps_proc, refs_proc):
        # sentence_score ควรใส่ refs เป็น list[list[str]] สำหรับหลาย reference
        s = bleu.sentence_score(h, [r])
        scores.append(s.score)  # 0..100
    return scores

def compute_bertscore_per_sentence(hyps: List[str], refs: List[str], model_type: str) -> pd.DataFrame:
    """
    คำนวณ BERTScore แบบ batch ทั้งชุด แล้วแตกค่าต่อบรรทัด
    คืน DataFrame มีคอลัมน์: bert_P, bert_R, bert_F1 (0..1)
    """
    P, R, F = bert_score(hyps, refs, model_type=model_type, verbose=True)
    return pd.DataFrame({
        "BERT_P":  P.tolist(),
        "BERT_R":  R.tolist(),
        "BERT_F1": F.tolist(),
    })

# %%
# ========= Load =========
df = pd.read_excel(XLSX_PATH)
print("Columns:")
for i, c in enumerate(df.columns):
    print(f"{i:>2}: {c}")

# ======= CHOOSE COLUMNS HERE =======
# เลือก "reference" (มาตรฐานทอง): ใส่ชื่อคอลัมน์ หรือใส่เลข index ตามที่พิมพ์ด้านบน
# ตัวอย่างที่เห็นในสกรีนช็อต: อาจใช้คอลัมน์ข้อความต้นฉบับภาษาไทยเป็น reference
REF_COL = "translate eng to thai (gpt 4o)"      # <-- แก้ให้ตรงของคุณ
# หรือใช้ index แทน เช่น REF_COL = df.columns[?]

# เลือกหลายคอลัมน์ของ “ผลลัพธ์โมเดล” เพื่อเปรียบเทียบพร้อมกัน (คำนวณให้ทุกคอลัมน์)
HYP_COLS = [
    "translate eng to thai (typhoon)",          # <-- แก้/เพิ่มได้ตามต้องการ
    # "translate thai to eng(typhoon)",         # ตัวอย่างเพิ่ม
]
# ถ้าอยากเลือกด้วยดัชนี: HYP_COLS = [df.columns[3], df.columns[6]]
# Out:
# Columns:
#  0: Unnamed: 0
#  1: Sentiment
#  2: translate thai to eng(typhoon)
#  3: Prompt: https://chatgpt.com/share/67cf709b-eb64-8004-b4b4-ab0952f5f375
#  4: translate eng to thai (typhoon)
#  5: BLEU
#  6: BERT score
#  7: translate eng to thai (gpt 4o)
#  8: Prompt: https://chatgpt.com/share/67cb7fa2-5e88-8004-bb5a-8f79db7a46f7
#  9: Prompt: https://chatgpt.com/share/67cf8dbe-0358-8004-9064-06a64d22f2f6
# 10: update compare result (Neutral is accepted)
# 11: Prompt: https://chatgpt.com/share/67cf8f8d-e5a8-8004-978f-4f7bede836b5
# 12: Prompt: https://chatgpt.com/share/67cf8f79-37b0-8004-8c3f-fd0c4906020a
# 13: Unnamed: 13
# 14: Unnamed: 14
# 15: Unnamed: 15

# %%
# ======= Validate =======
if REF_COL not in df.columns:
    raise ValueError(f"REF_COL '{REF_COL}' not found. ใช้ชื่อคอลัมน์ให้ตรงหรือเปลี่ยนเป็นดัชนีเช่น df.columns[3].")
for col in HYP_COLS:
    if col not in df.columns:
        raise ValueError(f"HYP_COL '{col}' not found. ตรวจสอบชื่อคอลัมน์: {list(df.columns)}")

ref_list = df[REF_COL].astype(str).fillna("").tolist()

# ลบผลเก่า (ถ้ามี) เพื่อไม่ให้ซ้ำ
for c in list(df.columns):
    if re.search(r"^BLEU_sent|^BERT_", c):
        df.drop(columns=[c], inplace=True, errors="ignore")

# %%
# ======= Compute for each hypothesis column =======
for hyp_col in HYP_COLS:
    hyps = df[hyp_col].astype(str).fillna("").tolist()
    print(f"\nScoring against REF='{REF_COL}'  HYP='{hyp_col}'")

    df[f"BLEU_sent :: {hyp_col}"] = bleu_sentence_list(hyps, ref_list, use_seg=USE_THAI_WORD_SEG)

    bdf = bertscore_df(hyps, ref_list, model_type=BERT_MODEL)
    df[f"BERT_P :: {hyp_col}"]  = bdf["BERT_P"]
    df[f"BERT_R :: {hyp_col}"]  = bdf["BERT_R"]
    df[f"BERT_F1 :: {hyp_col}"] = bdf["BERT_F1"]
# Out:
# WARNING:sacrebleu:It is recommended to enable `effective_order` for sentence-level BLEU.
# WARNING:sacrebleu:It is recommended to enable `effective_order` for sentence-level BLEU.
# WARNING:sacrebleu:It is recommended to enable `effective_order` for sentence-level BLEU.
# WARNING:sacrebleu:It is recommended to enable `effective_order` for sentence-level BLEU.
# WARNING:sacrebleu:It is recommended to enable `effective_order` for sentence-level BLEU.
# WARNING:sacrebleu:It is recommended to enable `effective_order` for sentence-level BLEU.
# WARNING:sacrebleu:It is recommended to enable `effective_order` for sentence-level BLEU.
# WARNING:sacrebleu:It is recommended to enable `effective_order` for sentence-level BLEU.
# WARNING:sacrebleu:It is recommended to enable `effective_order` for sentence-level BLEU.
# WARNING:sacrebleu:It is recommended to enable `effective_order` for sentence-level BLEU.
# WARNING:sacrebleu:It is recommended to enable `effective_order` for sentence-level BLEU.
# WARNING:sacrebleu:It is recommended to enable `effective_order` for sentence-level BLEU.
# WARNING:sacrebleu:It is recommended to enable `effective_order` for sentence-level BLEU.
# WARNING:sacrebleu:It is recommended to enable `effective_order` for sentence-level BLEU.
# WARNING:sacrebleu:It is recommended to enable `effective_order` for sentence-level BLEU.
# WARNING:sacrebleu:It is recommended to enable `effective_order` for sentence-level BLEU.
# WARNING:sacrebleu:It is recommended to enable `effective_order` for sentence-level BLEU.
# WARNING:sacrebleu:It is recommended to enable `effective_order` for sentence-level BLEU.
# WARNING:sacrebleu:It is recommended to enable `effective_order` for sentence-level BLEU.
# WARNING:sacrebleu:It is recommended to enable `effective_order` for sentence-level BLEU.
# WARNING:sacrebleu:It is recommended to enable `effective_order` for sentence-level BLEU.
# WARNING:sacrebleu:It is recommended to enable `effective_order` for sentence-level BLEU.
# WARNING:sacrebleu:It is recommended to enable `effective_order` for sentence-level BLEU.
# WARNING:sacrebleu:It is recommended to enable `effective_order` for sentence-level BLEU.
# WARNING:sacrebleu:It is recommended to enable `effective_order` for sentence-level BLEU.
# WARNING:sacrebleu:It is recommended to enable `effective_order` for sentence-level BLEU.
# WARNING:sacrebleu:It is recommended to enable `effective_order` for sentence-level BLEU.
# WARNING:sacrebleu:It is recommended to enable `effective_order` for sentence-level BLEU.
# WARNING:sacrebleu:It is recommended to enable `effective_order` for sentence-level BLEU.
# WARNING:sacrebleu:It is recommended to enable `effective_order` for sentence-level BLEU.
# WARNING:sacrebleu:It is recommended to enable `effective_order` for sentence-level BLEU.
# WARNING:sacrebleu:It is recommended to enable `effective_order` for sentence-level BLEU.
# WARNING:sacrebleu:It is recommended to enable `effective_order` for sentence-level BLEU.
# WARNING:sacrebleu:It is recommended to enable `effective_order` for sentence-level BLEU.
# WARNING:sacrebleu:It is recommended to enable `effective_order` for sentence-level BLEU.
# WARNING:sacrebleu:It is recommended to enable `effective_order` for sentence-level BLEU.
# WARNING:sacrebleu:It is recommended to enable `effective_order` for sentence-level BLEU.
# WARNING:sacrebleu:It is recommended to enable `effective_order` for sentence-level BLEU.
# WARNING:sacrebleu:It is recommended to enable `effective_order` for sentence-level BLEU.
# WARNING:sacrebleu:It is recommended to enable `effective_order` for sentence-level BLEU.
# WARNING:sacrebleu:It is recommended to enable `effective_order` for sentence-level BLEU.
# WARNING:sacrebleu:It is recommended to enable `effective_order` for sentence-level BLEU.
# WARNING:sacrebleu:It is recommended to enable `effective_order` for sentence-level BLEU.
# WARNING:sacrebleu:It is recommended to enable `effective_order` for sentence-level BLEU.
# WARNING:sacrebleu:It is recommended to enable `effective_order` for sentence-level BLEU.
# WARNING:sacrebleu:It is recommended to enable `effective_order` for sentence-level BLEU.
# WARNING:sacrebleu:It is recommended to enable `effective_order` for sentence-level BLEU.
# WARNING:sacrebleu:It is recommended to enable `effective_order` for sentence-level BLEU.
# WARNING:sacrebleu:It is recommended to enable `effective_order` for sentence-level BLEU.
# WARNING:sacrebleu:It is recommended to enable `effective_order` for sentence-level BLEU.
# WARNING:sacrebleu:It is recommended to enable `effective_order` for sentence-level BLEU.
# Scoring against REF='translate eng to thai (gpt 4o)'  HYP='translate eng to thai (typhoon)'

# %%
df.to_excel(SAVE_PATH, index=False)
print(f"\n✅ Saved to: {SAVE_PATH}")
# Out:
# ✅ Saved to: /content/MMT4NL_result_scored.xlsx

# %%
from google.colab import files
files.download("/content/MMT4NL_result_scored.xlsx")

# %%
df
# Out:
#      Unnamed: 0                                    Sentiment  \
# 0   sentimentID                                          NaN
# 1             1            ฉันมีความสุขมากที่ได้พบเพื่อนใหม่
# 2             2                       วันนี้อากาศดีและสดชื่น
# 3             3        หล่อนรู้สึกเสียใจที่ไม่สามารถไปงานได้
# 4             4                        อาหารมื้อนี้อร่อยสุดๆ
# 5             5                 ฉันไม่พอใจกับบริการที่ได้รับ
# 6           NaN             หนังเรื่องนี้น่าเบื่อและยืดเยื้อ
# 7           NaN                  เขาตื่นเต้นกับโอกาสครั้งนี้
# 8           NaN               เขาทำงานหนักและได้ผลลัพธ์ที่ดี
# 9           NaN                        ฉันกลัวว่าจะทำผิดพลาด
# 10          NaN             การเดินทางครั้งนี้สนุกและน่าจดจำ
# 11          NaN                       ฉันเบื่อกับการรอคอยนาน
# 12          NaN            เขาช่วยฉันแก้ปัญหาได้อย่างรวดเร็ว
# 13          NaN                    ฉันรู้สึกเหนื่อยและหมดแรง
# 14          NaN                        งานนี้ท้าทายแต่ก็สนุก
# 15          NaN                 ฉันผิดหวังกับคุณภาพสินค้านี้
# 16          NaN                     เพลงนี้ทำให้ฉันรู้สึกสงบ
# 17          NaN                    ฉันเกลียดการจราจรที่แออัด
# 18          NaN     วันนี้ฉันรู้สึกเฉยๆ ไม่มีอะไรเปลี่ยนแปลง
# 19          NaN               เราภูมิใจในความสำเร็จของตัวเอง
# 20          NaN                    ฉันไม่ชอบกลิ่นอาหารจานนี้
# 21          NaN            เพื่อนร่วมงานของฉันช่วยเหลือดีมาก
# 22          NaN      ฉันไม่แน่ใจเกี่ยวกับการตัดสินใจครั้งนี้
# 23          NaN                     พวกเขาพึงพอใจกับผลการสอบ
# 24          NaN           การประชุมวันนี้น่าเบื่อและเสียเวลา
# 25          NaN     ฉันรู้สึกอบอุ่นใจเมื่อได้อยู่กับครอบครัว
# 26          NaN                   ฉันรู้สึกผิดที่ลืมวันสำคัญ
# 27          NaN            หนังสือเล่มนี้ให้แรงบันดาลใจดีมาก
# 28          NaN                    ฉันไม่สามารถทนเสียงดังได้
# 29          NaN                 ฉันตื่นเต้นที่จะเริ่มงานใหม่
# 30          NaN                ฉันรู้สึกเครียดกับกำหนดส่งงาน
# 31          NaN                 คำชมของคุณทำให้ฉันยิ้มไม่หุบ
# 32          NaN                   ฉันหงุดหงิดเมื่อสิ่งของหาย
# 33          NaN           บรรยากาศร้านนี้เงียบสงบและผ่อนคลาย
# 34          NaN              ฉันรู้สึกแย่ที่ทำให้คนอื่นลำบาก
# 35          NaN         ฉันตื่นเต้นกับการเดินทางไปต่างประเทศ
# 36          NaN                  ฉันเบื่อชีวิตประจำวันแบบนี้
# 37          NaN                เราดีใจที่ได้ช่วยเหลือผู้อื่น
# 38          NaN                 ฉันไม่พอใจกับการจัดการของทีม
# 39          NaN              ฉันรู้สึกมั่นใจในทักษะของตัวเอง
# 40          NaN                        ฉันกลัวว่าจะถูกปฏิเสธ
# 41          NaN  การออกกำลังกายทำให้ฉันรู้สึกกระปรี้กระเปร่า
# 42          NaN                ฉันรู้สึกเซ็งเมื่อฝนตกทั้งวัน
# 43          NaN          ฉันมีความหวังว่าวันพรุ่งนี้จะดีขึ้น
# 44          NaN     ฉันไม่แน่ใจว่าตัวเลือกนี้ดีที่สุดหรือไม่
# 45          NaN                 กาแฟแก้วนี้ช่วยให้ฉันตื่นตัว
# 46          NaN           เขารู้สึกผิดหวังเมื่อแพ้การแข่งขัน
# 47          NaN              บทเรียนนี้ยาก แต่เธอตั้งใจเรียน
# 48          NaN                    ฉันเบื่อดูโทรทัศน์ทั้งวัน
# 49          NaN                    ฉันชื่นชมผลงานศิลปะนี้มาก
# 50          NaN                 ฉันรู้สึกกังวลเกี่ยวกับอนาคต
#
#                        translate thai to eng(typhoon)  \
# 0                                                 NaN
# 1                I am very happy to meet new friends.
# 2           The weather today is good and refreshing.
# 3       She feels sad that she can't go to the event.
# 4                   This meal is extremely delicious.
# 5     I am not satisfied with the service I received.
# 6                 This movie is boring and drawn out.
# 7               He is excited about this opportunity.
# 8                He worked hard and got good results.
# 9                     I am afraid of making mistakes.
# 10                   This trip was fun and memorable.
# 11                 I am tired of waiting for so long.
# 12            He helped me solve the problem quickly.
# 13                        I feel tired and exhausted.
# 14              This job is challenging but also fun.
# 15  I am disappointed with the quality of this pro...
# 16                      This song makes me feel calm.
# 17                               I hate traffic jams.
# 18    Today, I feel indifferent; nothing has changed.
# 19                  We are proud of our achievements.
# 20               I don't like the smell of this dish.
# 21                    My colleagues are very helpful.
# 22                   I am unsure about this decision.
# 23          They are satisfied with the exam results.
# 24    Today's meeting was boring and a waste of time.
# 25  I feel warm and comforted when I am with my fa...
# 26     I feel guilty for forgetting an important day.
# 27                       This book is very inspiring.
# 28                     I cannot tolerate loud noises.
# 29                   I am excited to start a new job.
# 30                I feel stressed about the deadline.
# 31           Your compliments made me smile non-stop.
# 32              I get annoyed when things go missing.
# 33  The atmosphere in this restaurant is quiet and...
# 34             I feel bad for causing others trouble.
# 35               I am excited about traveling abroad.
# 36                I am bored with this daily routine.
# 37                 We are glad to have helped others.
# 38     I am not satisfied with the team's management.
# 39                     I feel confident in my skills.
# 40                     I am afraid of being rejected.
# 41                  Exercise makes me feel energetic.
# 42                 I feel down when it rains all day.
# 43                    I hope tomorrow will be better.
# 44            I am unsure if this option is the best.
# 45            This cup of coffee helps me stay awake.
# 46  He felt disappointed when he lost the competit...
# 47  This lesson is difficult, but she studies dili...
# 48            I am bored watching television all day.
# 49                     I greatly admire this artwork.
# 50                   I feel worried about the future.
#
#    Prompt: https://chatgpt.com/share/67cf709b-eb64-8004-b4b4-ab0952f5f375  \
# 0                                            taxonomy
# 1            I am very delighted to meet new friends.
# 2       The weather today is pleasant and refreshing.
# 3     She feels upset that she can’t go to the event.
# 4                 This meal is extremely scrumptious.
# 5       I am not pleased with the service I received.
# 6                   This movie is boring and lengthy.
# 7              He is thrilled about this opportunity.
# 8          He worked diligently and got good results.
# 9                     I am scared of making mistakes.
# 10               This trip was fun and unforgettable.
# 11                 I am weary of waiting for so long.
# 12        He helped me solve the problem efficiently.
# 13                          I feel tired and drained.
# 14                This job is demanding but also fun.
# 15  I am disappointed with the standard of this pr...
# 16                  This song makes me feel peaceful.
# 17                            I despise traffic jams.
# 18    Today, I feel indifferent; nothing has shifted.
# 19               We are proud of our accomplishments.
# 20                I don’t like the odor of this dish.
# 21                 My colleagues are very supportive.
# 22                I am uncertain about this decision.
# 23         They are satisfied with the exam outcomes.
# 24  Today’s meeting was boring and a waste of energy.
# 25     I feel warm and safe when I am with my family.
# 26        I feel guilty for missing an important day.
# 27                      This book is very motivating.
# 28                        I cannot stand loud noises.
# 29                I am excited to start a new career.
# 30                I feel stressed about the timeline.
# 31          Your compliments made me smile endlessly.
# 32              I get annoyed when things go missing.
# 33  The atmosphere in this restaurant is quiet and...
# 34       I feel bad for causing others inconvenience.
# 35             I am excited about traveling overseas.
# 36                I am tired with this daily routine.
# 37               We are glad to have assisted others.
# 38     I am not satisfied with the team’s leadership.
# 39                       I feel assured in my skills.
# 40                      I am afraid of being ignored.
# 41                Exercise makes me feel invigorated.
# 42             I feel down when it rains all daylong.
# 43                  I hope tomorrow will be brighter.
# 44           I am unsure if this option is the right.
# 45            This cup of coffee helps me stay alert.
# 46  He felt disappointed when he failed the compet...
# 47  This lesson is difficult, but she studies pers...
# 48      I am bored watching television all afternoon.
# 49                 I greatly admire this masterpiece.
# 50                  I feel worried about the unknown.
#
#                       translate eng to thai (typhoon)  BLEU  BERT score  \
# 0                                                 NaN   NaN         NaN
# 1                   ฉันมีความสุขมากที่ได้พบเพื่อนใหม่   NaN         NaN
# 2                     อากาศวันนี้สดชื่นและน่ารื่นรมย์   NaN         NaN
# 3                   เธอเสียใจที่ไม่สามารถไปร่วมงานได้   NaN         NaN
# 4                          อาหารมื้อนี้อร่อยอย่างยิ่ง   NaN         NaN
# 5                        ฉันไม่พอใจกับบริการที่ได้รับ   NaN         NaN
# 6                    หนังเรื่องนี้ไม่สนุกและยาวเกินไป   NaN         NaN
# 7                           เขาตื่นเต้นกับโอกาสนี้มาก   NaN         NaN
# 8          เขาทำงานอย่างขยันขันแข็งและได้ผลลัพธ์ที่ดี   NaN         NaN
# 9                               ฉันกลัวที่จะทำผิดพลาด   NaN         NaN
# 10                              ทริปนี้สนุกและน่าจดจำ   NaN         NaN
# 11                 ฉันเบื่อหน่ายกับการรอคอยนานขนาดนี้   NaN         NaN
# 12            เขาช่วยฉันแก้ปัญหาได้อย่างมีประสิทธิภาพ   NaN         NaN
# 13                          ฉันรู้สึกเหนื่อยและหมดแรง   NaN         NaN
# 14                          งานนี้ท้าทายแต่ก็สนุกด้วย   NaN         NaN
# 15                ฉันผิดหวังกับมาตรฐานของผลิตภัณฑ์นี้   NaN         NaN
# 16                           เพลงนี้ทำให้ฉันรู้สึกสงบ   NaN         NaN
# 17                            ฉันเกลียดการจราจรติดขัด   NaN         NaN
# 18         วันนี้ฉันรู้สึกเฉยเมย ไม่มีอะไรเปลี่ยนแปลง   NaN         NaN
# 19                     พวกเราภูมิใจในความสำเร็จของเรา   NaN         NaN
# 20                       ฉันไม่ชอบกลิ่นของอาหารจานนี้   NaN         NaN
# 21                 เพื่อนร่วมงานของฉันให้กำลังใจดีมาก   NaN         NaN
# 22                      ฉันไม่แน่ใจเกี่ยวกับเรื่องนี้   NaN         NaN
# 23                              พวกเขาพอใจกับผลการสอบ   NaN         NaN
# 24  การประชุมวันนี้ไม่สนุกและเป็นการสิ้นเปลืองพลังงาน   NaN         NaN
# 25      ฉันรู้สึกอบอุ่นและปลอดภัยเมื่ออยู่กับครอบครัว   NaN         NaN
# 26                      ฉันรู้สึกผิดที่พลาดวันสำคัญไป   NaN         NaN
# 27                  หนังสือเล่มนี้สร้างแรงบันดาลใจมาก   NaN         NaN
# 28                                ฉันทนเสียงดังไม่ไหว   NaN         NaN
# 29                  ฉันตื่นเต้นที่จะเริ่มต้นอาชีพใหม่   NaN         NaN
# 30                  ฉันรู้สึกเครียดเกี่ยวกับกำหนดเวลา   NaN         NaN
# 31      คำชมของคุณทำให้ฉันยิ้มได้อย่างไม่มีที่สิ้นสุด   NaN         NaN
# 32                       ฉันหงุดหงิดเมื่อสิ่งของหายไป   NaN         NaN
# 33      บรรยากาศในร้านอาหารแห่งนี้เงียบสงบและผ่อนคลาย   NaN         NaN
# 34              ฉันรู้สึกเสียใจที่ทำให้คนอื่นไม่สะดวก   NaN         NaN
# 35               ฉันตื่นเต้นกับการเดินทางไปต่างประเทศ   NaN         NaN
# 36              ฉันเบื่อหน่ายกับกิจวัตรประจำวันแบบนี้   NaN         NaN
# 37            พวกเรารู้สึกยินดีที่ได้ช่วยเหลือผู้อื่น   NaN         NaN
# 38                     ฉันไม่พอใจกับการนำทีมของทีมนี้   NaN         NaN
# 39                          ฉันมั่นใจในทักษะของตัวเอง   NaN         NaN
# 40                               ฉันกลัวว่าจะถูกละเลย   NaN         NaN
# 41        การออกกำลังกายทำให้ฉันรู้สึกกระปรี้กระเปร่า   NaN         NaN
# 42                     ฉันรู้สึกเศร้าเมื่อฝนตกทั้งวัน   NaN         NaN
# 43                    ฉันหวังว่าพรุ่งนี้จะสดใสกว่านี้   NaN         NaN
# 44            ฉันไม่แน่ใจว่าตัวเลือกนี้ถูกต้องหรือไม่   NaN         NaN
# 45                       กาแฟแก้วนี้ช่วยให้ฉันตื่นตัว   NaN         NaN
# 46          เขารู้สึกผิดหวังเมื่อเขาไม่ผ่านการแข่งขัน   NaN         NaN
# 47      บทเรียนนี้ยาก แต่เธอตั้งใจเรียนอย่างต่อเนื่อง   NaN         NaN
# 48              ฉันเบื่อหน่ายกับการดูโทรทัศน์ทั้งบ่าย   NaN         NaN
# 49               ฉันชื่นชมผลงานชิ้นเอกนี้เป็นอย่างมาก   NaN         NaN
# 50                  ฉันกังวลเกี่ยวกับสิ่งที่ยังไม่รู้   NaN         NaN
#
#                      translate eng to thai (gpt 4o)  \
# 0                                               NaN
# 1                 ฉันมีความสุขมากที่ได้พบเพื่อนใหม่
# 2                            วันนี้อากาศดีและสดชื่น
# 3               เธอรู้สึกเสียใจที่ไม่สามารถไปงานได้
# 4                              อาหารมื้อนี้อร่อยมาก
# 5                      ฉันไม่พอใจกับบริการที่ได้รับ
# 6                  หนังเรื่องนี้น่าเบื่อและยืดเยื้อ
# 7                      เขารู้สึกตื่นเต้นกับโอกาสนี้
# 8                    เขาทำงานหนักและได้ผลลัพธ์ที่ดี
# 9                             ฉันกลัวว่าจะทำผิดพลาด
# 10                 การเดินทางครั้งนี้สนุกและน่าจดจำ
# 11                          ฉันเหนื่อยกับการรอมานาน
# 12                เขาช่วยฉันแก้ปัญหาได้อย่างรวดเร็ว
# 13                        ฉันรู้สึกเหนื่อยและหมดแรง
# 14                            งานนี้ท้าทายแต่ก็สนุก
# 15                  ฉันผิดหวังกับคุณภาพของสินค้านี้
# 16                         เพลงนี้ทำให้ฉันรู้สึกสงบ
# 17                                   ฉันเกลียดรถติด
# 18         วันนี้ฉันรู้สึกเฉยๆ ไม่มีอะไรเปลี่ยนแปลง
# 19                     เราภูมิใจกับความสำเร็จของเรา
# 20                     ฉันไม่ชอบกลิ่นของอาหารจานนี้
# 21                เพื่อนร่วมงานของฉันช่วยเหลือดีมาก
# 22               ฉันไม่แน่ใจเกี่ยวกับการตัดสินใจนี้
# 23                               พวกเขาพอใจกับผลสอบ
# 24               การประชุมวันนี้น่าเบื่อและเสียเวลา
# 25     ฉันรู้สึกอบอุ่นและสบายใจเมื่ออยู่กับครอบครัว
# 26                       ฉันรู้สึกผิดที่ลืมวันสำคัญ
# 27                  หนังสือเล่มนี้ให้แรงบันดาลใจมาก
# 28                              ฉันทนเสียงดังไม่ได้
# 29               ฉันรู้สึกตื่นเต้นที่จะเริ่มงานใหม่
# 30                              ฉันเครียดกับเส้นตาย
# 31                    คำชมของคุณทำให้ฉันยิ้มไม่หยุด
# 32                        ฉันรู้สึกรำคาญเมื่อของหาย
# 33           บรรยากาศในร้านอาหารนี้เงียบและผ่อนคลาย
# 34                  ฉันรู้สึกแย่ที่ทำให้คนอื่นลำบาก
# 35             ฉันตื่นเต้นกับการเดินทางไปต่างประเทศ
# 36                       ฉันเบื่อกับกิจวัตรประจำวัน
# 37                    เราดีใจที่ได้ช่วยเหลือผู้อื่น
# 38                     ฉันไม่พอใจกับการจัดการของทีม
# 39                        ฉันมั่นใจในทักษะของตัวเอง
# 40                            ฉันกลัวว่าจะถูกปฏิเสธ
# 41               การออกกำลังกายทำให้ฉันรู้สึกมีพลัง
# 42                   ฉันรู้สึกหดหู่เมื่อฝนตกทั้งวัน
# 43                       ฉันหวังว่าพรุ่งนี้จะดีขึ้น
# 44  ฉันไม่แน่ใจว่านี่เป็นทางเลือกที่ดีที่สุดหรือไม่
# 45                     กาแฟถ้วยนี้ช่วยให้ฉันตื่นตัว
# 46               เขารู้สึกผิดหวังเมื่อแพ้การแข่งขัน
# 47                บทเรียนนี้ยาก แต่เธอก็ตั้งใจเรียน
# 48                  ฉันเบื่อกับการดูโทรทัศน์ทั้งวัน
# 49                 ฉันชื่นชมงานศิลปะชิ้นนี้อย่างมาก
# 50                     ฉันรู้สึกกังวลเกี่ยวกับอนาคต
#
#    Prompt: https://chatgpt.com/share/67cb7fa2-5e88-8004-bb5a-8f79db7a46f7  \
# 0                                                 ner
# 1             Lily is very happy to meet new friends.
# 2           The weather today is good and refreshing.
# 3      Emma feels sad that she can’t go to the event.
# 4                   This meal is extremely delicious.
# 5   Ben is not satisfied with the service he recei...
# 6                 This movie is boring and drawn out.
# 7              Leo is excited about this opportunity.
# 8             Chris worked hard and got good results.
# 9                   Mia is afraid of making mistakes.
# 10                   This trip was fun and memorable.
# 11              Noah is tired of waiting for so long.
# 12         Ethan helped me solve the problem quickly.
# 13                     Ava feels tired and exhausted.
# 14              This job is challenging but also fun.
# 15  Isla is disappointed with the quality of this ...
# 16                  This song makes Olivia feel calm.
# 17                           Liam hates traffic jams.
# 18  Today, Grace feels indifferent; nothing has ch...
# 19  Daniel and Chloe are proud of their achievements.
# 20         Lucas doesn’t like the smell of this dish.
# 21                    My colleagues are very helpful.
# 22                 Zoe is unsure about this decision.
# 23  Mason and Ella are satisfied with the exam res...
# 24    Today’s meeting was boring and a waste of time.
# 25  Natalie feels warm and comforted when she is w...
# 26  Sophia feels guilty for forgetting an importan...
# 27                       This book is very inspiring.
# 28                  Owen cannot tolerate loud noises.
# 29                Lily is excited to start a new job.
# 30           Ethan feels stressed about the deadline.
# 31         Your compliments made Ruby smile non-stop.
# 32          Jack gets annoyed when things go missing.
# 33  The atmosphere in this restaurant is quiet and...
# 34       Hannah feels bad for causing others trouble.
# 35           Jacob is excited about traveling abroad.
# 36            Emily is bored with this daily routine.
# 37    Sophie and Ryan are glad to have helped others.
# 38  Nathan is not satisfied with the team’s manage...
# 39            Isabella feels confident in her skills.
# 40                   Eli is afraid of being rejected.
# 41                 Exercise makes Ava feel energetic.
# 42             Liam feels down when it rains all day.
# 43              Olivia hopes tomorrow will be better.
# 44          Leo is unsure if this option is the best.
# 45         This cup of coffee helps Mason stay awake.
# 46  Caleb felt disappointed when he lost the compe...
# 47  This lesson is difficult, but Grace studies di...
# 48         Noah is bored watching television all day.
# 49                 Aria greatly admires this artwork.
# 50               Ella feels worried about the future.
#
#    Prompt: https://chatgpt.com/share/67cf8dbe-0358-8004-9064-06a64d22f2f6  \
# 0                                            negation
# 1          I am very not unhappy to meet new friends.
# 2        The weather today is not bad and refreshing.
# 3   She feels not happy that she can’t go to the e...
# 4                             This meal is not bland.
# 5       I am unsatisfied with the service I received.
# 6       This movie is not entertaining and drawn out.
# 7      He is not uninterested about this opportunity.
# 8             He worked hard and got not bad results.
# 9           I am not confident about making mistakes.
# 10            This trip was not boring and memorable.
# 11              I am not patient waiting for so long.
# 12         He helped me solve the problem not slowly.
# 13                    I feel tired and not energetic.
# 14               This job is not boring but also fun.
# 15  I am not impressed with the quality of this pr...
# 16               This song makes me feel not anxious.
# 17                        I do not like traffic jams.
# 18  Today, I feel indifferent; not excited about a...
# 19            We are not ashamed of our achievements.
# 20                  I dislike the smell of this dish.
# 21                   My colleagues are not unhelpful.
# 22                 I am not sure about this decision.
# 23        They are not unhappy with the exam results.
# 24  Today’s meeting was not engaging and a waste o...
# 25  I feel not cold and alone when I am with my fa...
# 26  I feel not proud for forgetting an important day.
# 27                      This book is very not boring.
# 28                        I do not enjoy loud noises.
# 29               I am not nervous to start a new job.
# 30                I feel not calm about the deadline.
# 31                Your compliments made me not frown.
# 32            I get not happy when things go missing.
# 33         The atmosphere is not noisy and stressful.
# 34        I feel not good for causing others trouble.
# 35                I am not dreading traveling abroad.
# 36        I am not entertained by this daily routine.
# 37        We are not regretful to have helped others.
# 38       I am unsatisfied with the team’s management.
# 39                  I feel not insecure in my skills.
# 40          I am not comfortable with being rejected.
# 41               Exercise makes me feel not sluggish.
# 42         I feel not cheerful when it rains all day.
# 43            I do not wish for tomorrow to be worse.
# 44        I am not confident this option is the best.
# 45       This cup of coffee helps me not fall asleep.
# 46  He felt not satisfied when he lost the competi...
# 47  This lesson is not easy, but she studies dilig...
# 48  I am not entertained watching television all day.
# 49                     I do not dislike this artwork.
# 50               I feel not relaxed about the future.
#
#    update compare result (Neutral is accepted)  \
# 0                           negation (updated)
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
# 5                                          NaN
# 6                                          NaN
# 7                                          NaN
# 8                                          NaN
# 9                                          NaN
# 10                                         NaN
# 11                                         NaN
# 12                                         NaN
# 13                                         NaN
# 14                                         NaN
# 15                                         NaN
# 16                                         NaN
# 17                                         NaN
# 18                                         NaN
# 19                                         NaN
# 20                                         NaN
# 21                                         NaN
# 22                                         NaN
# 23                                         NaN
# 24                                         NaN
# 25                                         NaN
# 26                                         NaN
# 27                                         NaN
# 28                                         NaN
# 29                                         NaN
# 30                                         NaN
# 31                                         NaN
# 32                                         NaN
# 33                                         NaN
# 34                                         NaN
# 35                                         NaN
# 36                                         NaN
# 37                                         NaN
# 38                                         NaN
# 39                                         NaN
# 40                                         NaN
# 41                                         NaN
# 42                                         NaN
# 43                                         NaN
# 44                                         NaN
# 45                                         NaN
# 46                                         NaN
# 47                                         NaN
# 48                                         NaN
# 49                                         NaN
# 50                                         NaN
#
#    Prompt: https://chatgpt.com/share/67cf8f8d-e5a8-8004-978f-4f7bede836b5  \
# 0                                               vocab
# 1          I am very truly happy to meet new friends.
# 2   The weather today is good and wonderfully refr...
# 3   She feels truly sad that she can’t go to the e...
# 4        This meal is extremely absolutely delicious.
# 5   I am not fully satisfied with the service I re...
# 6          This movie is boring and overly drawn out.
# 7     He is genuinely excited about this opportunity.
# 8     He worked incredibly hard and got good results.
# 9              I am deeply afraid of making mistakes.
# 10        This trip was fun and incredibly memorable.
# 11      I am tired of constantly waiting for so long.
# 12      He helped me solve the problem quite quickly.
# 13             I feel tired and completely exhausted.
# 14    This job is challenging but also genuinely fun.
# 15  I am disappointed with the overall quality of ...
# 16           This song makes me feel incredibly calm.
# 17                    I absolutely hate traffic jams.
# 18  Today, I feel completely indifferent; nothing ...
# 19            We are truly proud of our achievements.
# 20        I don’t like the strong smell of this dish.
# 21         My colleagues are very incredibly helpful.
# 22             I am still unsure about this decision.
# 23    They are fully satisfied with the exam results.
# 24  Today’s meeting was boring and honestly a wast...
# 25  I feel warm and genuinely comforted when I am ...
# 26  I feel deeply guilty for forgetting an importa...
# 27                This book is very deeply inspiring.
# 28          I cannot personally tolerate loud noises.
# 29         I am extremely excited to start a new job.
# 30        I feel stressed about the looming deadline.
# 31      Your kind compliments made me smile non-stop.
# 32    I get extremely annoyed when things go missing.
# 33  The atmosphere in this restaurant is quiet and...
# 34  I feel bad for unintentionally causing others ...
# 35          I am excited about traveling abroad soon.
# 36           I am bored with this dull daily routine.
# 37       We are genuinely glad to have helped others.
# 38  I am not fully satisfied with the team’s manag...
# 39             I feel confident in my current skills.
# 40          I am afraid of being completely rejected.
# 41          Exercise makes me feel totally energetic.
# 42      I feel down when it constantly rains all day.
# 43          I sincerely hope tomorrow will be better.
# 44    I am unsure if this current option is the best.
# 45      This cup of coffee helps me stay fully awake.
# 46  He felt disappointed when he unfortunately los...
# 47  This lesson is difficult, but she studies quit...
# 48  I am bored watching pointless television all day.
# 49           I greatly admire this beautiful artwork.
# 50         I feel worried about the uncertain future.
#
#    Prompt: https://chatgpt.com/share/67cf8f79-37b0-8004-8c3f-fd0c4906020a  \
# 0                                            fairness
# 1              She is very happy to meet new friends.
# 2   The weather today is good and refreshing for a...
# 3   The Thai girl feels sad that she can’t go to t...
# 4          This Japanese meal is extremely delicious.
# 5   I, as a Vietnamese customer, am not satisfied ...
# 6         This Chinese movie is boring and drawn out.
# 7   The Indian boy is excited about this opportunity.
# 8   He, a hardworking Filipino man, got good results.
# 9   I, a young Thai student, am afraid of making m...
# 10  This trip with my Singaporean friends was fun ...
# 11  I am tired of waiting for so long like a patie...
# 12  He, a kind-hearted Malay uncle, helped me solv...
# 13  I feel tired and exhausted like a Japanese sal...
# 14  This job is challenging but also fun for a you...
# 15  I am disappointed with the quality of this pro...
# 16    This song makes a Cambodian listener feel calm.
# 17            I, a Bangkok driver, hate traffic jams.
# 18  Today, a Chinese woman feels indifferent; noth...
# 19     We Singaporeans are proud of our achievements.
# 20  I don’t like the smell of this dish as a picky...
# 21           My Filipino colleagues are very helpful.
# 22  I am unsure about this decision as a young Jap...
# 23  The Thai students are satisfied with the exam ...
# 24  Today’s meeting was boring and a waste of time...
# 25  I feel warm and comforted when I am with my Th...
# 26  I feel guilty for forgetting an important day ...
# 27      This African-American book is very inspiring.
# 28  I, a noise-sensitive Thai person, cannot toler...
# 29  I am excited to start a new job in a Korean co...
# 30  I feel stressed about the deadline like a Mala...
# 31  Your compliments made the shy Japanese girl sm...
# 32  I get annoyed when things go missing like a Th...
# 33  The atmosphere in this Vietnamese restaurant i...
# 34  I feel bad for causing others trouble like a h...
# 35  I am excited about traveling abroad with my Si...
# 36  I am bored with this daily routine like a tire...
# 37      We Malaysians are glad to have helped others.
# 38  I am not satisfied with the Thai team’s manage...
# 39  I feel confident in my skills as a Japanese en...
# 40  I am afraid of being rejected like a nervous K...
# 41      Exercise makes the Thai woman feel energetic.
# 42        I feel down when it rains all day in Hanoi.
# 43  I hope tomorrow will be better for the Vietnam...
# 44  I am unsure if this option is the best for my ...
# 45  This cup of Vietnamese coffee helps me stay aw...
# 46  He, a proud Thai athlete, felt disappointed wh...
# 47  This lesson is difficult, but the Filipino gir...
# 48  I, a bored Thai teenager, am tired of watching...
# 49  I, a Japanese art lover, greatly admire this a...
# 50  I feel worried about the future like a graduat...
#
#    Unnamed: 13 Unnamed: 14         Unnamed: 15  \
# 0   robustness    temporal  temporal (updated)
# 1          NaN         NaN                 NaN
# 2          NaN         NaN                 NaN
# 3          NaN         NaN                 NaN
# 4          NaN         NaN                 NaN
# 5          NaN         NaN                 NaN
# 6          NaN         NaN                 NaN
# 7          NaN         NaN                 NaN
# 8          NaN         NaN                 NaN
# 9          NaN         NaN                 NaN
# 10         NaN         NaN                 NaN
# 11         NaN         NaN                 NaN
# 12         NaN         NaN                 NaN
# 13         NaN         NaN                 NaN
# 14         NaN         NaN                 NaN
# 15         NaN         NaN                 NaN
# 16         NaN         NaN                 NaN
# 17         NaN         NaN                 NaN
# 18         NaN         NaN                 NaN
# 19         NaN         NaN                 NaN
# 20         NaN         NaN                 NaN
# 21         NaN         NaN                 NaN
# 22         NaN         NaN                 NaN
# 23         NaN         NaN                 NaN
# 24         NaN         NaN                 NaN
# 25         NaN         NaN                 NaN
# 26         NaN         NaN                 NaN
# 27         NaN         NaN                 NaN
# 28         NaN         NaN                 NaN
# 29         NaN         NaN                 NaN
# 30         NaN         NaN                 NaN
# 31         NaN         NaN                 NaN
# 32         NaN         NaN                 NaN
# 33         NaN         NaN                 NaN
# 34         NaN         NaN                 NaN
# 35         NaN         NaN                 NaN
# 36         NaN         NaN                 NaN
# 37         NaN         NaN                 NaN
# 38         NaN         NaN                 NaN
# 39         NaN         NaN                 NaN
# 40         NaN         NaN                 NaN
# 41         NaN         NaN                 NaN
# 42         NaN         NaN                 NaN
# 43         NaN         NaN                 NaN
# 44         NaN         NaN                 NaN
# 45         NaN         NaN                 NaN
# 46         NaN         NaN                 NaN
# 47         NaN         NaN                 NaN
# 48         NaN         NaN                 NaN
# 49         NaN         NaN                 NaN
# 50         NaN         NaN                 NaN
#
#     BLEU_sent :: translate eng to thai (typhoon)  \
# 0                                       0.000000
# 1                                     100.000000
# 2                                      15.106877
# 3                                      49.626448
# 4                                      66.874030
# 5                                     100.000000
# 6                                      22.089591
# 7                                      53.728497
# 8                                      46.713798
# 9                                      24.736930
# 10                                     43.012509
# 11                                      8.643020
# 12                                     80.910671
# 13                                    100.000000
# 14                                     80.910671
# 15                                     27.776190
# 16                                    100.000000
# 17                                      0.000000
# 18                                     44.124845
# 19                                     32.466792
# 20                                    100.000000
# 21                                     42.728701
# 22                                     53.728497
# 23                                     30.213754
# 24                                     12.223076
# 25                                     59.694918
# 26                                     32.466792
# 27                                     37.991784
# 28                                     66.874030
# 29                                     16.341219
# 30                                      9.652435
# 31                                     43.361891
# 32                                     10.682175
# 33                                     27.054113
# 34                                     25.848658
# 35                                    100.000000
# 36                                     23.643540
# 37                                     41.113362
# 38                                     35.494811
# 39                                    100.000000
# 40                                     75.983569
# 41                                     66.874030
# 42                                     37.991784
# 43                                     51.697315
# 44                                     25.124219
# 45                                     64.345888
# 46                                     36.555522
# 47                                     51.334505
# 48                                     26.269099
# 49                                     15.207218
# 50                                     12.223076
#
#     BERT_P :: translate eng to thai (typhoon)  \
# 0                                    1.000000
# 1                                    1.000000
# 2                                    0.952192
# 3                                    0.960317
# 4                                    0.981483
# 5                                    1.000000
# 6                                    0.921924
# 7                                    0.969957
# 8                                    0.927457
# 9                                    0.957687
# 10                                   0.972128
# 11                                   0.888971
# 12                                   0.959580
# 13                                   1.000000
# 14                                   0.996662
# 15                                   0.966498
# 16                                   1.000000
# 17                                   0.940470
# 18                                   0.949723
# 19                                   0.936193
# 20                                   1.000000
# 21                                   0.941496
# 22                                   0.948997
# 23                                   0.995156
# 24                                   0.928737
# 25                                   0.979354
# 26                                   0.928345
# 27                                   0.989351
# 28                                   0.941538
# 29                                   0.961529
# 30                                   0.898574
# 31                                   0.930496
# 32                                   0.895684
# 33                                   0.981552
# 34                                   0.916685
# 35                                   1.000000
# 36                                   0.939504
# 37                                   0.914586
# 38                                   0.953446
# 39                                   1.000000
# 40                                   0.937028
# 41                                   0.901804
# 42                                   0.972918
# 43                                   0.944333
# 44                                   0.951667
# 45                                   0.990310
# 46                                   0.944142
# 47                                   0.981286
# 48                                   0.937053
# 49                                   0.948118
# 50                                   0.875587
#
#     BERT_R :: translate eng to thai (typhoon)  \
# 0                                    1.000000
# 1                                    1.000000
# 2                                    0.959062
# 3                                    0.958576
# 4                                    0.980838
# 5                                    1.000000
# 6                                    0.897250
# 7                                    0.983332
# 8                                    0.969975
# 9                                    0.950040
# 10                                   0.971147
# 11                                   0.947985
# 12                                   0.969627
# 13                                   1.000000
# 14                                   0.998971
# 15                                   0.966498
# 16                                   1.000000
# 17                                   0.962046
# 18                                   0.964847
# 19                                   0.959814
# 20                                   1.000000
# 21                                   0.956187
# 22                                   0.934496
# 23                                   0.995156
# 24                                   0.953497
# 25                                   0.960199
# 26                                   0.959799
# 27                                   0.973530
# 28                                   0.964899
# 29                                   0.966886
# 30                                   0.900383
# 31                                   0.975002
# 32                                   0.933038
# 33                                   0.994987
# 34                                   0.940902
# 35                                   1.000000
# 36                                   0.969231
# 37                                   0.952254
# 38                                   0.932057
# 39                                   1.000000
# 40                                   0.942863
# 41                                   0.959485
# 42                                   0.927159
# 43                                   0.973084
# 44                                   0.938652
# 45                                   0.990310
# 46                                   0.972182
# 47                                   0.982577
# 48                                   0.979843
# 49                                   0.966120
# 50                                   0.923518
#
#     BERT_F1 :: translate eng to thai (typhoon)
# 0                                     1.000000
# 1                                     1.000000
# 2                                     0.955615
# 3                                     0.959446
# 4                                     0.981160
# 5                                     1.000000
# 6                                     0.909420
# 7                                     0.976599
# 8                                     0.948240
# 9                                     0.953849
# 10                                    0.971637
# 11                                    0.917530
# 12                                    0.964578
# 13                                    1.000000
# 14                                    0.997815
# 15                                    0.966498
# 16                                    1.000000
# 17                                    0.951136
# 18                                    0.957225
# 19                                    0.947856
# 20                                    1.000000
# 21                                    0.948784
# 22                                    0.941690
# 23                                    0.995156
# 24                                    0.940955
# 25                                    0.969682
# 26                                    0.943810
# 27                                    0.981377
# 28                                    0.953075
# 29                                    0.964200
# 30                                    0.899478
# 31                                    0.952229
# 32                                    0.913979
# 33                                    0.988224
# 34                                    0.928636
# 35                                    1.000000
# 36                                    0.954136
# 37                                    0.933040
# 38                                    0.942631
# 39                                    1.000000
# 40                                    0.939937
# 41                                    0.929751
# 42                                    0.949488
# 43                                    0.958493
# 44                                    0.945114
# 45                                    0.990310
# 46                                    0.957956
# 47                                    0.981931
# 48                                    0.957970
# 49                                    0.957034
# 50                                    0.898914

# %%
#BlUE
#print double check row 18
